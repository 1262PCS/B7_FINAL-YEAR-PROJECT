# %%
# !pip install torch-geometric

# %%
# !pip install networkx matplotlib

# %%
# !pip install networkx torch scikit-learn

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid
import networkx as nx
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# # LOADING CORA WITH PAPER TITLES

# %%
# !wget https://people.cs.umass.edu/~mccallum/data/cora.tar.gz
# Out:
# --2023-12-13 13:59:29--  https://people.cs.umass.edu/~mccallum/data/cora.tar.gz
# Resolving people.cs.umass.edu (people.cs.umass.edu)... 128.119.240.99
# Connecting to people.cs.umass.edu (people.cs.umass.edu)|128.119.240.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 264768650 (253M) [application/x-gzip]
# Saving to: ‘cora.tar.gz’
#
# cora.tar.gz         100%[===================>] 252.50M  44.3MB/s    in 6.2s
#
# 2023-12-13 13:59:36 (41.0 MB/s) - ‘cora.tar.gz’ saved [264768650/264768650]

# %% [markdown]
# # Extracting contents of dataset

# %%
# !tar -zxvf cora.tar.gz

# %% [markdown]
# # Load cora.content File into a DataFrame

# %%
df = pd.read_csv('/content/cora/papers', sep='\t', header=None, names=['paper_id', 'word_attributes', 'class_label'])

# %% [markdown]
# #  Load Cora Dataset using PyTorch Geometric

# %%
dataset = Planetoid(root='.', name='Cora')
data = dataset[0]
aligned_titles = df["class_label"].tolist()
aligned_indices = df["paper_id"].tolist()

# %% [markdown]
# # Define a Simple Graph Convolutional Network (GCN) Model

# %%
class GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

# %% [markdown]
# # Instantiate the Model, Loss Function, and Optimizer

# %%
model = GCN(in_channels=dataset.num_node_features, hidden_channels=16, out_channels=dataset.num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# %% [markdown]
# # Training and Testing FunctionsNew Section

# %%
def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()

def test():
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    acc = accuracy_score(data.y[data.test_mask].numpy(), pred[data.test_mask].numpy())
    return acc

# %% [markdown]
# # Training Loop

# %%
num_epochs = 200
for epoch in range(1, num_epochs + 1):
    loss = train()
    acc = test()
    print(f'Epoch: {epoch}, Loss: {loss:.4f}, Test Accuracy: {acc:.4f}')
# Out:
# Epoch: 1, Loss: 1.9589, Test Accuracy: 0.4340
# Epoch: 2, Loss: 1.8543, Test Accuracy: 0.5950
# Epoch: 3, Loss: 1.7209, Test Accuracy: 0.6210
# Epoch: 4, Loss: 1.5539, Test Accuracy: 0.6120
# Epoch: 5, Loss: 1.3960, Test Accuracy: 0.6290
# Epoch: 6, Loss: 1.2453, Test Accuracy: 0.6830
# Epoch: 7, Loss: 1.0968, Test Accuracy: 0.7310
# Epoch: 8, Loss: 0.9563, Test Accuracy: 0.7620
# Epoch: 9, Loss: 0.8273, Test Accuracy: 0.7730
# Epoch: 10, Loss: 0.7113, Test Accuracy: 0.7790
# Epoch: 11, Loss: 0.6076, Test Accuracy: 0.7830
# Epoch: 12, Loss: 0.5161, Test Accuracy: 0.7840
# Epoch: 13, Loss: 0.4361, Test Accuracy: 0.7890
# Epoch: 14, Loss: 0.3674, Test Accuracy: 0.7920
# Epoch: 15, Loss: 0.3091, Test Accuracy: 0.7890
# Epoch: 16, Loss: 0.2604, Test Accuracy: 0.7860
# Epoch: 17, Loss: 0.2195, Test Accuracy: 0.7860
# Epoch: 18, Loss: 0.1852, Test Accuracy: 0.7840
# Epoch: 19, Loss: 0.1562, Test Accuracy: 0.7830
# Epoch: 20, Loss: 0.1320, Test Accuracy: 0.7830
# Epoch: 21, Loss: 0.1118, Test Accuracy: 0.7790
# Epoch: 22, Loss: 0.0951, Test Accuracy: 0.7840
# Epoch: 23, Loss: 0.0814, Test Accuracy: 0.7860
# Epoch: 24, Loss: 0.0699, Test Accuracy: 0.7870
# Epoch: 25, Loss: 0.0604, Test Accuracy: 0.7870
# Epoch: 26, Loss: 0.0525, Test Accuracy: 0.7850
# Epoch: 27, Loss: 0.0459, Test Accuracy: 0.7870
# Epoch: 28, Loss: 0.0404, Test Accuracy: 0.7900
# Epoch: 29, Loss: 0.0359, Test Accuracy: 0.7890
# Epoch: 30, Loss: 0.0321, Test Accuracy: 0.7880
# Epoch: 31, Loss: 0.0289, Test Accuracy: 0.7900
# Epoch: 32, Loss: 0.0263, Test Accuracy: 0.7910
# Epoch: 33, Loss: 0.0240, Test Accuracy: 0.7920
# Epoch: 34, Loss: 0.0221, Test Accuracy: 0.7940
# Epoch: 35, Loss: 0.0205, Test Accuracy: 0.7950
# Epoch: 36, Loss: 0.0192, Test Accuracy: 0.7940
# Epoch: 37, Loss: 0.0180, Test Accuracy: 0.7930
# Epoch: 38, Loss: 0.0170, Test Accuracy: 0.7930
# Epoch: 39, Loss: 0.0162, Test Accuracy: 0.7930
# Epoch: 40, Loss: 0.0155, Test Accuracy: 0.7930
# Epoch: 41, Loss: 0.0149, Test Accuracy: 0.7910
# Epoch: 42, Loss: 0.0144, Test Accuracy: 0.7920
# Epoch: 43, Loss: 0.0140, Test Accuracy: 0.7920
# Epoch: 44, Loss: 0.0137, Test Accuracy: 0.7930
# Epoch: 45, Loss: 0.0134, Test Accuracy: 0.7930
# Epoch: 46, Loss: 0.0132, Test Accuracy: 0.7940
# Epoch: 47, Loss: 0.0130, Test Accuracy: 0.7940
# Epoch: 48, Loss: 0.0129, Test Accuracy: 0.7960
# Epoch: 49, Loss: 0.0129, Test Accuracy: 0.7940
# Epoch: 50, Loss: 0.0128, Test Accuracy: 0.7940
# Epoch: 51, Loss: 0.0128, Test Accuracy: 0.7940
# Epoch: 52, Loss: 0.0129, Test Accuracy: 0.7950
# Epoch: 53, Loss: 0.0129, Test Accuracy: 0.7950
# Epoch: 54, Loss: 0.0130, Test Accuracy: 0.7950
# Epoch: 55, Loss: 0.0131, Test Accuracy: 0.7960
# Epoch: 56, Loss: 0.0132, Test Accuracy: 0.7970
# Epoch: 57, Loss: 0.0134, Test Accuracy: 0.7970
# Epoch: 58, Loss: 0.0135, Test Accuracy: 0.7980
# Epoch: 59, Loss: 0.0137, Test Accuracy: 0.7980
# Epoch: 60, Loss: 0.0138, Test Accuracy: 0.8000
# Epoch: 61, Loss: 0.0140, Test Accuracy: 0.8000
# Epoch: 62, Loss: 0.0142, Test Accuracy: 0.8010
# Epoch: 63, Loss: 0.0144, Test Accuracy: 0.8020
# Epoch: 64, Loss: 0.0145, Test Accuracy: 0.8010
# Epoch: 65, Loss: 0.0147, Test Accuracy: 0.8020
# Epoch: 66, Loss: 0.0149, Test Accuracy: 0.8020
# Epoch: 67, Loss: 0.0151, Test Accuracy: 0.8020
# Epoch: 68, Loss: 0.0152, Test Accuracy: 0.8020
# Epoch: 69, Loss: 0.0154, Test Accuracy: 0.8020
# Epoch: 70, Loss: 0.0155, Test Accuracy: 0.8020
# Epoch: 71, Loss: 0.0157, Test Accuracy: 0.8020
# Epoch: 72, Loss: 0.0158, Test Accuracy: 0.8030
# Epoch: 73, Loss: 0.0159, Test Accuracy: 0.8040
# Epoch: 74, Loss: 0.0160, Test Accuracy: 0.8040
# Epoch: 75, Loss: 0.0161, Test Accuracy: 0.8050
# Epoch: 76, Loss: 0.0162, Test Accuracy: 0.8060
# Epoch: 77, Loss: 0.0163, Test Accuracy: 0.8050
# Epoch: 78, Loss: 0.0163, Test Accuracy: 0.8050
# Epoch: 79, Loss: 0.0164, Test Accuracy: 0.8060
# Epoch: 80, Loss: 0.0164, Test Accuracy: 0.8060
# Epoch: 81, Loss: 0.0164, Test Accuracy: 0.8070
# Epoch: 82, Loss: 0.0165, Test Accuracy: 0.8070
# Epoch: 83, Loss: 0.0165, Test Accuracy: 0.8070
# Epoch: 84, Loss: 0.0164, Test Accuracy: 0.8070
# Epoch: 85, Loss: 0.0164, Test Accuracy: 0.8070
# Epoch: 86, Loss: 0.0164, Test Accuracy: 0.8060
# Epoch: 87, Loss: 0.0164, Test Accuracy: 0.8070
# Epoch: 88, Loss: 0.0163, Test Accuracy: 0.8070
# Epoch: 89, Loss: 0.0163, Test Accuracy: 0.8080
# Epoch: 90, Loss: 0.0162, Test Accuracy: 0.8080
# Epoch: 91, Loss: 0.0162, Test Accuracy: 0.8080
# Epoch: 92, Loss: 0.0161, Test Accuracy: 0.8070
# Epoch: 93, Loss: 0.0160, Test Accuracy: 0.8070
# Epoch: 94, Loss: 0.0160, Test Accuracy: 0.8080
# Epoch: 95, Loss: 0.0159, Test Accuracy: 0.8090
# Epoch: 96, Loss: 0.0158, Test Accuracy: 0.8080
# Epoch: 97, Loss: 0.0157, Test Accuracy: 0.8090
# Epoch: 98, Loss: 0.0156, Test Accuracy: 0.8090
# Epoch: 99, Loss: 0.0155, Test Accuracy: 0.8090
# Epoch: 100, Loss: 0.0155, Test Accuracy: 0.8080
# Epoch: 101, Loss: 0.0154, Test Accuracy: 0.8080
# Epoch: 102, Loss: 0.0153, Test Accuracy: 0.8060
# Epoch: 103, Loss: 0.0152, Test Accuracy: 0.8060
# Epoch: 104, Loss: 0.0151, Test Accuracy: 0.8060
# Epoch: 105, Loss: 0.0150, Test Accuracy: 0.8060
# Epoch: 106, Loss: 0.0149, Test Accuracy: 0.8060
# Epoch: 107, Loss: 0.0149, Test Accuracy: 0.8060
# Epoch: 108, Loss: 0.0148, Test Accuracy: 0.8070
# Epoch: 109, Loss: 0.0147, Test Accuracy: 0.8080
# Epoch: 110, Loss: 0.0146, Test Accuracy: 0.8070
# Epoch: 111, Loss: 0.0145, Test Accuracy: 0.8070
# Epoch: 112, Loss: 0.0144, Test Accuracy: 0.8070
# Epoch: 113, Loss: 0.0143, Test Accuracy: 0.8070
# Epoch: 114, Loss: 0.0143, Test Accuracy: 0.8070
# Epoch: 115, Loss: 0.0142, Test Accuracy: 0.8070
# Epoch: 116, Loss: 0.0141, Test Accuracy: 0.8070
# Epoch: 117, Loss: 0.0140, Test Accuracy: 0.8070
# Epoch: 118, Loss: 0.0140, Test Accuracy: 0.8070
# Epoch: 119, Loss: 0.0139, Test Accuracy: 0.8060
# Epoch: 120, Loss: 0.0138, Test Accuracy: 0.8060
# Epoch: 121, Loss: 0.0137, Test Accuracy: 0.8060
# Epoch: 122, Loss: 0.0137, Test Accuracy: 0.8060
# Epoch: 123, Loss: 0.0136, Test Accuracy: 0.8060
# Epoch: 124, Loss: 0.0135, Test Accuracy: 0.8060
# Epoch: 125, Loss: 0.0135, Test Accuracy: 0.8040
# Epoch: 126, Loss: 0.0134, Test Accuracy: 0.8040
# Epoch: 127, Loss: 0.0133, Test Accuracy: 0.8030
# Epoch: 128, Loss: 0.0133, Test Accuracy: 0.8030
# Epoch: 129, Loss: 0.0132, Test Accuracy: 0.8030
# Epoch: 130, Loss: 0.0131, Test Accuracy: 0.8030
# Epoch: 131, Loss: 0.0131, Test Accuracy: 0.8030
# Epoch: 132, Loss: 0.0130, Test Accuracy: 0.8030
# Epoch: 133, Loss: 0.0130, Test Accuracy: 0.8030
# Epoch: 134, Loss: 0.0129, Test Accuracy: 0.8030
# Epoch: 135, Loss: 0.0129, Test Accuracy: 0.8030
# Epoch: 136, Loss: 0.0128, Test Accuracy: 0.8040
# Epoch: 137, Loss: 0.0127, Test Accuracy: 0.8040
# Epoch: 138, Loss: 0.0127, Test Accuracy: 0.8040
# Epoch: 139, Loss: 0.0126, Test Accuracy: 0.8040
# Epoch: 140, Loss: 0.0126, Test Accuracy: 0.8040
# Epoch: 141, Loss: 0.0125, Test Accuracy: 0.8040
# Epoch: 142, Loss: 0.0125, Test Accuracy: 0.8040
# Epoch: 143, Loss: 0.0124, Test Accuracy: 0.8040
# Epoch: 144, Loss: 0.0124, Test Accuracy: 0.8040
# Epoch: 145, Loss: 0.0123, Test Accuracy: 0.8040
# Epoch: 146, Loss: 0.0123, Test Accuracy: 0.8040
# Epoch: 147, Loss: 0.0122, Test Accuracy: 0.8040
# Epoch: 148, Loss: 0.0122, Test Accuracy: 0.8040
# Epoch: 149, Loss: 0.0121, Test Accuracy: 0.8040
# Epoch: 150, Loss: 0.0121, Test Accuracy: 0.8050
# Epoch: 151, Loss: 0.0120, Test Accuracy: 0.8050
# Epoch: 152, Loss: 0.0120, Test Accuracy: 0.8050
# Epoch: 153, Loss: 0.0119, Test Accuracy: 0.8050
# Epoch: 154, Loss: 0.0119, Test Accuracy: 0.8050
# Epoch: 155, Loss: 0.0119, Test Accuracy: 0.8060
# Epoch: 156, Loss: 0.0118, Test Accuracy: 0.8060
# Epoch: 157, Loss: 0.0118, Test Accuracy: 0.8060
# Epoch: 158, Loss: 0.0117, Test Accuracy: 0.8060
# Epoch: 159, Loss: 0.0117, Test Accuracy: 0.8060
# Epoch: 160, Loss: 0.0116, Test Accuracy: 0.8060
# Epoch: 161, Loss: 0.0116, Test Accuracy: 0.8060
# Epoch: 162, Loss: 0.0116, Test Accuracy: 0.8070
# Epoch: 163, Loss: 0.0115, Test Accuracy: 0.8070
# Epoch: 164, Loss: 0.0115, Test Accuracy: 0.8060
# Epoch: 165, Loss: 0.0114, Test Accuracy: 0.8060
# Epoch: 166, Loss: 0.0114, Test Accuracy: 0.8060
# Epoch: 167, Loss: 0.0113, Test Accuracy: 0.8070
# Epoch: 168, Loss: 0.0113, Test Accuracy: 0.8070
# Epoch: 169, Loss: 0.0113, Test Accuracy: 0.8060
# Epoch: 170, Loss: 0.0112, Test Accuracy: 0.8060
# Epoch: 171, Loss: 0.0112, Test Accuracy: 0.8060
# Epoch: 172, Loss: 0.0112, Test Accuracy: 0.8070
# Epoch: 173, Loss: 0.0111, Test Accuracy: 0.8070
# Epoch: 174, Loss: 0.0111, Test Accuracy: 0.8080
# Epoch: 175, Loss: 0.0110, Test Accuracy: 0.8080
# Epoch: 176, Loss: 0.0110, Test Accuracy: 0.8080
# Epoch: 177, Loss: 0.0110, Test Accuracy: 0.8080
# Epoch: 178, Loss: 0.0109, Test Accuracy: 0.8080
# Epoch: 179, Loss: 0.0109, Test Accuracy: 0.8080
# Epoch: 180, Loss: 0.0109, Test Accuracy: 0.8080
# Epoch: 181, Loss: 0.0108, Test Accuracy: 0.8080
# Epoch: 182, Loss: 0.0108, Test Accuracy: 0.8070
# Epoch: 183, Loss: 0.0108, Test Accuracy: 0.8070
# Epoch: 184, Loss: 0.0107, Test Accuracy: 0.8070
# Epoch: 185, Loss: 0.0107, Test Accuracy: 0.8080
# Epoch: 186, Loss: 0.0107, Test Accuracy: 0.8080
# Epoch: 187, Loss: 0.0106, Test Accuracy: 0.8080
# Epoch: 188, Loss: 0.0106, Test Accuracy: 0.8080
# Epoch: 189, Loss: 0.0106, Test Accuracy: 0.8080
# Epoch: 190, Loss: 0.0105, Test Accuracy: 0.8080
# Epoch: 191, Loss: 0.0105, Test Accuracy: 0.8080
# Epoch: 192, Loss: 0.0105, Test Accuracy: 0.8080
# Epoch: 193, Loss: 0.0104, Test Accuracy: 0.8080
# Epoch: 194, Loss: 0.0104, Test Accuracy: 0.8080
# Epoch: 195, Loss: 0.0104, Test Accuracy: 0.8080
# Epoch: 196, Loss: 0.0104, Test Accuracy: 0.8080
# Epoch: 197, Loss: 0.0103, Test Accuracy: 0.8080
# Epoch: 198, Loss: 0.0103, Test Accuracy: 0.8080
# Epoch: 199, Loss: 0.0103, Test Accuracy: 0.8080
# Epoch: 200, Loss: 0.0102, Test Accuracy: 0.8080

# %%
# Final Evaluation
model.eval()
out = model(data.x, data.edge_index)
pred = out.argmax(dim=1)
acc = accuracy_score(data.y[data.test_mask].numpy(), pred[data.test_mask].numpy())
num_features = out.shape[1]  # Number of output features

# Print final evaluation details
print(f'Final Evaluation - Loss: {loss:.4f}, Test Accuracy: {acc:.4f}, Num Features: {num_features}')
# Out:
# Final Evaluation - Loss: 0.0076, Test Accuracy: 0.8050, Num Features: 7

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plotting
epochs = np.arange(1, num_epochs + 1)
plt.figure(figsize=(12, 5))

# Plot Training Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Training Loss', color='blue')
plt.title('Training Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()



plt.tight_layout()
plt.show()

# %% [markdown]
# #  Visualize the Graph

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

def visualize_graph(data):
    G = nx.Graph()
    edge_index = data.edge_index.cpu().numpy()
    for i in range(edge_index.shape[1]):
        src, tgt = edge_index[0, i], edge_index[1, i]
        G.add_edge(src, tgt)

    pos = nx.spring_layout(G)
    plt.figure(figsize=(12, 8))

    # Draw the graph
    nx.draw(G, pos, with_labels=False, node_color=data.y.cpu().numpy(), cmap="Set1")

    # Create a color legend
    unique_classes = sorted(set(data.y.cpu().numpy()))
    class_names = {
        0: 'Theory',
        1: 'Reinforcement Learning',
        2: 'Genetic Algorithms',
        3: 'Neural Networks',
        4: 'Probabilistic Methods',
        5: 'Case Based',
        6: 'Rule Learning'
    }

    color_map = plt.cm.get_cmap("Set1", len(unique_classes))

    handles = []
    for i, class_label in enumerate(unique_classes):
        class_name = class_names[class_label]
        patch = mpatches.Patch(color=color_map(i), label=class_name)
        handles.append(patch)

    plt.legend(handles=handles, title="Class", bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.title("Cora Dataset - Node Classification")
    plt.show()

# Visualize the graph
visualize_graph(data)
# Out:
# <ipython-input-38-fec60c6e5cea>:30: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = plt.cm.get_cmap("Set1", len(unique_classes))

# %% [markdown]
# # Display Paper Titles Under Various Categories After Classification

# %%
model.eval()
out = model(data.x, data.edge_index)
predicted_labels = out.argmax(dim=1)
category_titles = {category: [] for category in range(dataset.num_classes)}

for idx, label in enumerate(predicted_labels):
    # Find the original index in the dataframe based on PyG's node indices
    mask_indices = (data.test_mask.nonzero().view(-1) == idx).nonzero()

    # Check if the index is found and within the bounds of the aligned_titles list
    if mask_indices.numel() > 0:
        original_idx = mask_indices.item()
        if original_idx < len(aligned_titles):
            category_titles[label.item()].append(aligned_titles[original_idx])

# %%
# !pip install ipywidgets

# %%
import re
import pandas as pd
import ipywidgets as widgets
from IPython.display import display

# Class_labels_to_names dictionary that maps class labels to category names
class_labels_to_names = {
    0: 'Theory',
    1: 'Reinforcement_Learning',
    2: 'Genetic_Algorithms',
    3: 'Neural_Networks',
    4: 'Probabilistic_Methods',
    5: 'Case_Based',
    6: 'Rule_Learning'
}



# Set the model to evaluation mode
model.eval()

# Forward pass to get predictions
out = model(data.x, data.edge_index)

# Get predicted labels
predicted_labels = out.argmax(dim=1)

# Replace class labels with category names
predicted_category_names = [class_labels_to_names[label.item()] for label in predicted_labels]

# Create a dictionary to store lists of titles for each category
category_titles = {category_name: [] for category_name in class_labels_to_names.values()}


# Loop through predicted category names and aligned titles
for idx, category_name in enumerate(predicted_category_names):
    # Find the original index in the dataframe based on PyG's node indices
    mask_indices = (data.test_mask.nonzero().view(-1) == idx).nonzero()

    # Check if the index is found and within the bounds of the aligned_titles list
    if mask_indices.numel() > 0:
        original_idx = mask_indices.item()
        if original_idx < len(aligned_titles):
            # Remove words within < > and </ > tags using regular expressions
            cleaned_title = re.sub(r'<[^>]*>', '', aligned_titles[original_idx])

            # Append the cleaned title to the corresponding category's list
            category_titles[category_name].append(cleaned_title)

# Create separate DataFrames for each category
category_dataframes = {}
for category_name, paper_titles in category_titles.items():
    df_category = pd.DataFrame({'Paper Titles': paper_titles})
    category_dataframes[category_name] = df_category

# Create a dropdown widget with category names
category_dropdown = widgets.Dropdown(options=['__Choose Here__'] + list(category_dataframes.keys()), description='Domain')

# Create an output widget to display the selected category's table
output_widget = widgets.Output()

# Display the widgets
display(widgets.VBox([category_dropdown, output_widget]))

# Create a function to update the output based on the selected category
def update_output(change):
    selected_category = change.new

    if selected_category == '__Choose Here__':
        with output_widget:
            output_widget.clear_output(wait=True)
            print("Please choose a category.")
    else:
        df_category = category_dataframes[selected_category]
        num_papers = len(df_category)

        with output_widget:
            output_widget.clear_output(wait=True)
            print(f"\nPAPERS ON {selected_category} ({num_papers} papers):\n")

            # Center-align the paper titles
            df_category_styled = df_category.style.set_table_styles([
                {'selector': 'th', 'props': [('border', '1px solid black'), ('text-align', 'center')]},
                {'selector': 'td', 'props': [('border', '1px solid black'), ('text-align', 'center')]}
            ])
            display(df_category_styled)

# Connect the dropdown to the update function
category_dropdown.observe(update_output, names='value')
# Out:
# VBox(children=(Dropdown(description='Domain', options=('__Choose Here__', 'Theory', 'Reinforcement_Learning', …

# %% [markdown]
# # Search box and Display Papers Based on the Search Keyword

# %%
import re
import pandas as pd
import ipywidgets as widgets
from IPython.display import display


class_labels_to_names = {
    0: 'Theory',
    1: 'Reinforcement_Learning',
    2: 'Genetic_Algorithms',
    3: 'Neural_Networks',
    4: 'Probabilistic_Methods',
    5: 'Case_Based',
    6: 'Rule_Learning'
}



# Set the model to evaluation mode
model.eval()

# Forward pass to get predictions
out = model(data.x, data.edge_index)

# Get predicted labels
predicted_labels = out.argmax(dim=1)

# Replace class labels with category names
predicted_category_names = [class_labels_to_names[label.item()] for label in predicted_labels]

# Create a dictionary to store lists of titles for each category
category_titles = {category_name: [] for category_name in class_labels_to_names.values()}
category_titles['Miscellaneous'] = []

# Loop through predicted category names and aligned titles
for idx, category_name in enumerate(predicted_category_names):
    # Find the original index in the dataframe based on PyG's node indices
    mask_indices = (data.test_mask.nonzero().view(-1) == idx).nonzero()

    # Check if the index is found and within the bounds of the aligned_titles list
    if mask_indices.numel() > 0:
        original_idx = mask_indices.item()
        if original_idx < len(aligned_titles):
            # Remove words within < > and </ > tags using regular expressions
            cleaned_title = re.sub(r'<[^>]*>', '', aligned_titles[original_idx])

            # Append the cleaned title to the corresponding category's list
            category_titles[category_name].append(cleaned_title)

# Create a combined DataFrame for all categories
all_papers_df = pd.concat([pd.DataFrame({'Category': [category_name]*len(paper_titles), 'Paper Title': paper_titles})
                           for category_name, paper_titles in category_titles.items()], ignore_index=True)

# Create a search box for entering keywords
keyword_search = widgets.Text(placeholder='Enter keyword', description='Keyword:')

# Create an output widget to display the search results
output_widget = widgets.Output()

# Display the widgets
display(widgets.VBox([keyword_search, output_widget]))

# Create a function to update the output based on the entered keyword
def update_output(change):
    keyword = keyword_search.value.lower()  # Convert keyword to lowercase for case-insensitive search

    with output_widget:
        output_widget.clear_output(wait=True)

        # Filter papers based on the keyword
        if keyword:
            matching_papers = all_papers_df[all_papers_df['Paper Title'].str.lower().str.contains(keyword)]
            num_papers = len(matching_papers)

            print(f"\nSearch Results for '{keyword}' ({num_papers} papers):\n")

            # Center-align the paper titles
            matching_papers_styled = matching_papers.style.set_table_styles([
                {'selector': 'th', 'props': [('border', '1px solid black'), ('text-align', 'center')]},
                {'selector': 'td', 'props': [('border', '1px solid black'), ('text-align', 'center')]}
            ])
            display(matching_papers_styled)

# Connect the search box to the update function
keyword_search.observe(update_output, names='value')
# Out:
# VBox(children=(Text(value='', description='Keyword:', placeholder='Enter keyword'), Output()))
