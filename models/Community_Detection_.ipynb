# %%
# !pip install torch-geometric
# Out:
# Collecting torch-geometric
#   Downloading torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (4.66.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.11.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2023.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.9.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (2.31.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->torch-geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torch-geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->torch-geometric) (3.5.0)
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.5.3

# %%
# !pip install networkx matplotlib
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install networkx torch scikit-learn
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 43.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch_geometric.datasets import Planetoid
import networkx as nx
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# # Loading Cora with paper details

# %%
# !wget https://people.cs.umass.edu/~mccallum/data/cora.tar.gz
# Out:
# --2024-05-22 17:50:20--  https://people.cs.umass.edu/~mccallum/data/cora.tar.gz
# Resolving people.cs.umass.edu (people.cs.umass.edu)... 128.119.240.99
# Connecting to people.cs.umass.edu (people.cs.umass.edu)|128.119.240.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 264768650 (253M) [application/x-gzip]
# Saving to: ‘cora.tar.gz’
#
# cora.tar.gz         100%[===================>] 252.50M  44.5MB/s    in 5.7s
#
# 2024-05-22 17:50:26 (44.5 MB/s) - ‘cora.tar.gz’ saved [264768650/264768650]

# %% [markdown]
# Extracting contents of dataset

# %%
# !tar -zxvf cora.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#ornl.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Multip#TheParform.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Multip#mpossurvey.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Nbody#dfma.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Nbody#sc92.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Network#dqdbsim_0.2b#doc#ds_user.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#PADS#summary.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Papers#nanjing.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Papers#query.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Parsed#IC3Npaper#meng.ps
# cora/extractions/http:##www.cs.rpi.edu#~bagalp#prallel.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Parsed#IC3Npaper#paper-submit.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Simulation#Network#Solaris#Distr#Writing#MASECT#c-ready.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Simulation#pdes-survey.ps.gz
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#Research#Tcpemu#Writing#fulltcpsim.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#1995.TR130.LYDIA.D1.ps.z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#1995.TR131.LYDIA.D2.ps.z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#CSL-TR-94-601.ps.z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#PADS-survey-94.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#SPEEDESJournalPaper1.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#Sasos#sarc93-1.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#TR94-19.ps.gz
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#UW-CSE-93-03-01.PS.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#WWW#cornellcsrep.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#allocsrv.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#gcsurvey.ps.z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#m8.6.fr.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#mpicomp96.ps
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#mppl.ps.gz
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#TechRep#tr95-005.ps.z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#UNIX#paper.ps.Z
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#ccr-july96.ps.gz
# cora/extractions/http:##www.cs.panam.edu#~meng#unix-home#icp-squid.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#courses#spring97#GHMI#paperfmt#chi97.ps
# cora/extractions/http:##www.cs.rpi.edu#projects#pb#graphdraw#paper.ps
# cora/extractions/http:##www.cs.rpi.edu#research#tempest#gustdir#gust.ps.Z
# cora/extractions/http:##www.cs.rpi.edu#research#tempest#gustdir#gust.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~adjerids#research#papers#2dhier.ps
# cora/extractions/http:##www.cs.rpi.edu#~adjerids#research#papers#oxidation.ps
# cora/extractions/http:##www.cs.rpi.edu#~adjerids#research#papers#singular_ams.ps
# cora/extractions/http:##www.cs.rpi.edu#~bagalp#caicim98step#caicim98step.ps
# cora/extractions/http:##www.cs.rpi.edu#~bivenj#door_res.ps
# cora/extractions/http:##www.cs.rpi.edu#~blythes#docs#isss95.ps
# cora/extractions/http:##www.cs.rpi.edu#~blythes#docs#isss96.ps
# cora/extractions/http:##www.cs.rpi.edu#~blythes#docs#todaes97.ps
# cora/extractions/http:##www.cs.rpi.edu#~blythes#docs#tvlsi97.ps
# cora/extractions/http:##www.cs.rpi.edu#~bubnak#dbme.ps
# cora/extractions/http:##www.cs.rpi.edu#~bubnak#iccv.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#hawaii.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#pads97.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#pdpta.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#smc97.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#supeur96.ps
# cora/extractions/http:##www.cs.rpi.edu#~deelmane#wsc96.ps
# cora/extractions/http:##www.cs.rpi.edu#~diaza#Publications#comm.ps
# cora/extractions/http:##www.cs.rpi.edu#~diaza#Publications#jsc95.ps
# cora/extractions/http:##www.cs.rpi.edu#~diaza#Publications#sigsam.ps
# cora/extractions/http:##www.cs.rpi.edu#~dugan#gis93.ps
# cora/extractions/http:##www.cs.rpi.edu#~flaherje#ode2.ps
# cora/extractions/http:##www.cs.rpi.edu#~flaherje#ode3.ps
# cora/extractions/http:##www.cs.rpi.edu#~flaherje#ode5.ps
# cora/extractions/http:##www.cs.rpi.edu#~flaherje#odeintro.ps
# cora/extractions/http:##www.cs.rpi.edu#~flatland#pspapers#cccg96.ps.Z
# cora/extractions/http:##www.cs.rpi.edu#~fryp#papers#wip#metasystem.ps
# cora/extractions/http:##www.cs.rpi.edu#~harrisod#security#SecCommerce.ps
# cora/extractions/http:##www.cs.rpi.edu#~kondorfm#oop#nuwebdoc.ps
# cora/extractions/http:##www.cs.rpi.edu#~millerj#papers#gdm_thesis.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#deg.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#dimacs.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#jolly.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#joop.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#sched.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#subh.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#sv.ps
# cora/extractions/http:##www.cs.rpi.edu#~moorthy#MyResearch#Papers#triangle.ps
# cora/extractions/http:##www.cs.rpi.edu#~musser#ap#nuweb.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~musser#ap#wordfreq#freqword.ps
# cora/extractions/http:##www.cs.rpi.edu#~musser#gp#dagstuhl#gpdag.ps
# cora/extractions/http:##www.cs.rpi.edu#~musser#gp#gensearch.ps
# cora/extractions/http:##www.cs.rpi.edu#~musser#gp#introsort.ps
# cora/extractions/http:##www.cs.rpi.edu#~musser#gp#tecton#tecton1.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~musser#gp#traversals.ps
# cora/extractions/http:##www.cs.rpi.edu#~nibhanum#publications#europar96.ps
# cora/extractions/http:##www.cs.rpi.edu#~nibhanum#publications#hpcs98.ps
# cora/extractions/http:##www.cs.rpi.edu#~nibhanum#publications#rtspp98.ps
# cora/extractions/http:##www.cs.rpi.edu#~ohsumit#modcomp_lectures#grading.ps
# cora/extractions/http:##www.cs.rpi.edu#~satyar#bbn#ipatm#ipatm.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#94#compmeth#redist.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#94#imacs#load.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#95#ima#part.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#97#cmame#qmr.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#97#ima#ima.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#97#jpdc#jpdc.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#97#pdpta#pdpta.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#97#sccc#sccc.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#anm#anm.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#biomech#biomech.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#cmame#cmame.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#cmame#cmame.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#cvd#cvd.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#cvd#cvd.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#dundee#dundee.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#error#error.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#hier#hier.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#ices#ices.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#98#singpert#singpert.ps
# cora/extractions/http:##www.cs.rpi.edu#~scorec#papers#99#korneev#korneev.ps
# cora/extractions/http:##www.cs.rpi.edu#~shapiraa#papers#disctests#t.ps
# cora/extractions/http:##www.cs.rpi.edu#~shapiraa#papers#genexpts#t.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#mediation#whips#cube.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#coopis98.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#jlp96.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#kdex97.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#mmsj96.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#sigmod96.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#sigmod98.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#sigmod99.ps
# cora/extractions/http:##www.cs.rpi.edu#~sibel#research#papers#vlkb95.ps
# cora/extractions/http:##www.cs.rpi.edu#~steubeng#c++#Lecture1#lec1.handout.ps
# cora/extractions/http:##www.cs.rpi.edu#~terescoj#research#proposal#proposal.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~ulfar#mrst.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~wiseb#papers#PROPOSAL.ps
# cora/extractions/http:##www.cs.rpi.edu#~wiseb#papers#acmj.ps
# cora/extractions/http:##www.cs.rpi.edu#~wiseb#papers#ecdvrat96.ps
# cora/extractions/http:##www.cs.rpi.edu#~wiseb#papers#resna.ps
# cora/extractions/http:##www.cs.rpi.edu#~zaki#PS#CIKM98.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~zaki#PS#ICDE99.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~zaki#PS#THESIS.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~zalewskk#doc#unix#bellovin_tcp.ps.Z
# cora/extractions/http:##www.cs.rpi.edu#~ziantzl#Papers#94#PARLE#sparse.ps
# cora/extractions/http:##www.cs.rpi.edu#~ziantzl#Papers#96#Anm#anm.ps.gz
# cora/extractions/http:##www.cs.rpi.edu#~ziantzl#Papers#96#LCR_EPL#lcr.ps
# cora/extractions/http:##www.cs.rpi.edu#~ziantzl#Papers#96#SupEur#supeur.ps
# cora/extractions/http:##www.cs.rpi.edu#~ziantzl#Papers#97#pdpta#pdpta.ps
# cora/extractions/http:##www.cs.sunysb.edu#~abhik#transform#main.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~abhik#transform#tapd.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~abhik#transform#tr98.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#RPE.ps
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#addition-chain.ps
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#group-testing.ps
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#mod-survey.ps
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#revfinal.ps
# cora/extractions/http:##www.cs.sunysb.edu#~astiwari#rta-full.ps
# cora/extractions/http:##www.cs.sunysb.edu#~bcohen#chemAcm.ps
# cora/extractions/http:##www.cs.sunysb.edu#~davulcu#new.ps
# cora/extractions/http:##www.cs.sunysb.edu#~davulcu#paper.ps
# cora/extractions/http:##www.cs.sunysb.edu#~davulcu#ve.ps
# cora/extractions/http:##www.cs.sunysb.edu#~mitra#text.ps
# cora/extractions/http:##www.cs.sunysb.edu#~prashant#docs#fgffq.ps
# cora/extractions/http:##www.cs.sunysb.edu#~prashant#docs#infocomm.ps
# cora/extractions/http:##www.cs.sunysb.edu#~prashant#docs#rpe.ps
# cora/extractions/http:##www.cs.sunysb.edu#~prashant#docs#wlrether.ps
# cora/extractions/http:##www.cs.sunysb.edu#~qin#papers#tog94.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~qin#papers#tvcg96.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~qin#papers#tvcg98.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~sazaklis#thesis.ps.gz
# cora/extractions/http:##www.cs.sunysb.edu#~stark#REPORTS#delays.ps.Z
# cora/extractions/http:##www.cs.sunysb.edu#~vassilis#AI99.ps
# cora/extractions/http:##www.cs.sunysb.edu#~vassilis#iscc99-10.ps
# cora/extractions/http:##www.cs.sunysb.edu#~vassilis#tbs.ps
# cora/extractions/http:##www.cs.sunysb.edu#~vicdu#iProto.ps
# cora/extractions/http:##www.cs.sunysb.edu#~vicdu#lpmc.ps
# cora/extractions/http:##www.cs.sunysb.edu#~vicdu#rether.ps
# cora/extractions/http:##www.cs.swarthmore.edu#~marshall#analogy98-paper.ps.gz
# cora/extractions/http:##www.cs.tamu.edu
ps
# cora/extractions/http:##www.win.tue.nl#~hooman#PDPVS.ps
# cora/extractions/http:##www.win.tue.nl#~hooman#STEAM.ps
# cora/extractions/http:##www.win.tue.nl#~lavrauw#art1.ps
# cora/extractions/http:##www.win.tue.nl#~maubach#Research#Papers#maubach-paper24.ps
# cora/extractions/http:##www.win.tue.nl#~maubach#Research#Papers#maubach-paper29.ps
# cora/extractions/http:##www.win.tue.nl#~maubach#Research#Papers#maubach-paper31.ps
# cora/extractions/http:##www.win.tue.nl#~richard#Docs#conimp.ps
# cora/extractions/http:##www.win.tue.nl#~richard#Docs#ppg.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#atal96.ps
# cora/extractions/http:##www.win.tue.nl#~wsinkvo#PAPERS_PS#daniel.ps.gz
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap0.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap1.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap2.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap3.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap4.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap5.ps.Z
# cora/extractions/http:##wwwcg.win.tue.nl#~wstahw#Docs#Thesis#chap6.ps.Z
# cora/extractions/http:##wwwis.win.tue.nl#infwet97#proceedings#ProfilePars.ps
# cora/extractions/http:##wwwis.win.tue.nl#infwet97#proceedings#mmm97.ps
# cora/extractions/http:##wwwis.win.tue.nl#infwet97#proceedings#wondergem.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#csn94#csn94.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#joep#joep-thesis.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#riao94#explore.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#stinfon94#final.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#webnet-2#index.ps
# cora/extractions/http:##wwwis.win.tue.nl#~debra#webnet96#index.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#atal97gg.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#atal97imp.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#contracts.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#deon94.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#deon96.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#deon98.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#dexa97.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#ds6.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#hicss97.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#hicss98.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#icmas96.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#is-co94.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#ismis96.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#lap97.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#modelage96.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#modelage97.ps
# cora/extractions/http:##wwwis.win.tue.nl#~dignum#reason.ps
# cora/extractions/http:##wwwis.win.tue.nl#~hongjing#pub#ht99.ps
# cora/extractions/http:##wwwis.win.tue.nl#~houben#pub#metrics.ps.Z
# cora/extractions/http:##wwwis.win.tue.nl#~wsinatma#Agents#MSA.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinatma#Agents#isorc98.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinatma#Step.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinatma#trex.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#cii.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#cii_bpr.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#cimpro.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#dm.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#fms.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#ieee.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#inheritpn.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#ipic.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#jcsc.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#lcipn.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#mdpn_csn.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#nsf.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#pn93.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#orspec.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#pn97final.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#proc.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#rts.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#tigra.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#tools.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#wfm_adv.ps
# cora/extractions/http:##wwwis.win.tue.nl#~wsinwa#wfnetscsn.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.ave97.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.jbs_faces.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.josa-old.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.josa.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.pattern.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.perception.ps
# cora/extractions/http:##wwwpub.utdallas.edu#~herve#abdi.vae97.ps
# cora/extractions/http:##wwwx.cs.unc.edu#~aylward#proj_diss#IPMI97.ps.gz
# cora/extractions/http:##wwwx.cs.unc.edu#~aylward#proj_mri#aaai.ps.gz
# cora/extractions/http:##wwwx.cs.unc.edu#~aylward#proj_mri#vbc.ps.gz
# cora/extractions/http:##yugiri.brain.riken.go.jp#shigeru#topology.ps
# cora/extractions/http:##zhadum.cs.washington.edu#zamir#kdd97.ps
# cora/extractions/http:##zhadum.cs.washington.edu#zamir#quals.ps
# cora/extractions/paul.rutgers.edu#~nat#Papers#accuracy.ps.gz
# cora/extractions/paul.rutgers.edu#~nat#Papers#ijcai95-final.ps.gz
# cora/extractions/www.cs.bilkent.edu.tr#~oulusoy#dexa.ps.Z
# cora/extractions/www.cs.bilkent.edu.tr#~oulusoy#jss2.ps.Z
# cora/extractions/www.pitt.edu#~uxkst#flairs-97-paper.ps
# cora/extractions/http:##www.cs.jhu.edu#~junwu#eurospeech.ps
# cora/extractions/http:##www.cs.jhu.edu#~junwu#topic-lm.ps
# cora/extractions/http:##www.cs.pitt.edu#~suew#dexa98.ps
# cora/extractions/http:##www.cs.pitt.edu#~suew#icci98.ps
# cora/extractions/http:##www.cs.pitt.edu#~suew#mobiquery.ps
# cora/extractions/http:##www.ics.uci.edu#~sbay#papers#mfs_ida.ps
# cora/papers
# cora/classifications
# cora/citations.withauthors

# %% [markdown]
# # Load cora.content File into a DataFrame

# %%
df = pd.read_csv('/content/cora/papers', sep='\t', header=None, names=['paper_id', 'word_attributes', 'class_label'])

# %% [markdown]
# Load Cora Dataset using PyTorch Geometric

# %%
dataset = Planetoid(root='.', name='Cora')
data = dataset[0]
aligned_titles = df["class_label"].tolist()
aligned_indices = df["paper_id"].tolist()
# Out:
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!

# %% [markdown]
# # Define a Simple Graph Convolutional Network (GCN) Model

# %%
class GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)  # Changed to hidden_channels

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

# %% [markdown]
# Instantiate the Model, Loss Function, and Optimizer

# %%
model = GCN(in_channels=dataset.num_node_features, hidden_channels=16, out_channels=dataset.num_classes)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)

# %% [markdown]
# #Training and Testing Functions

# %%
def train():
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()

def test():
    model.eval()
    out = model(data.x, data.edge_index)
    pred = out.argmax(dim=1)
    acc = accuracy_score(data.y[data.test_mask].numpy(), pred[data.test_mask].numpy())
    return acc

# %% [markdown]
# Training Loop

# %%
num_epochs = 295
for epoch in range(1, num_epochs + 1):
    loss = train()
    acc = test()
    print(f'Epoch: {epoch}, Loss: {loss:.4f}, Test Accuracy: {acc:.4f}')
# Out:
# Epoch: 1, Loss: 1.9521, Test Accuracy: 0.4670
# Epoch: 2, Loss: 1.8533, Test Accuracy: 0.6050
# Epoch: 3, Loss: 1.7329, Test Accuracy: 0.6280
# Epoch: 4, Loss: 1.5915, Test Accuracy: 0.6280
# Epoch: 5, Loss: 1.4534, Test Accuracy: 0.6620
# Epoch: 6, Loss: 1.3155, Test Accuracy: 0.6960
# Epoch: 7, Loss: 1.1802, Test Accuracy: 0.7210
# Epoch: 8, Loss: 1.0495, Test Accuracy: 0.7370
# Epoch: 9, Loss: 0.9272, Test Accuracy: 0.7560
# Epoch: 10, Loss: 0.8144, Test Accuracy: 0.7650
# Epoch: 11, Loss: 0.7101, Test Accuracy: 0.7810
# Epoch: 12, Loss: 0.6142, Test Accuracy: 0.7860
# Epoch: 13, Loss: 0.5270, Test Accuracy: 0.7960
# Epoch: 14, Loss: 0.4488, Test Accuracy: 0.7980
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

G = nx.Graph()
edge_index = data.edge_index.cpu().numpy()
for i in range(edge_index.shape[1]):
    src, tgt = edge_index[0, i], edge_index[1, i]
    G.add_edge(src, tgt)

# %%
# Extract node embeddings as dictionary
node_embeddings = {}
for node, embedding in enumerate(out.cpu().detach().numpy()):
    node_embeddings[node] = embedding

print (node_embeddings)
# Add node embeddings as node attributes in NetworkX graph
nx.set_node_attributes(G, node_embeddings, 'embedding')
# Out:
# {0: array([-2.642615 , -1.5048738, -1.2853572,  5.5985417, -1.4047794,
#        -2.700307 , -1.653732 ], dtype=float32), 1: array([-1.1644564, -2.7977667, -2.609864 , -2.9298582,  7.679888 ,
#        -4.1594267, -1.6298056], dtype=float32), 2: array([-1.2289227 , -2.6193962 , -2.577128  ,  0.05005252,  5.942278  ,
#        -4.036719  , -2.2826219 ], dtype=float32), 3: array([ 5.8551064 , -1.0289059 , -3.2428741 , -3.1214461 , -1.0306115 ,
#        -3.639703  , -0.47884363], dtype=float32), 4: array([-2.1234882, -1.6991004, -0.5743236,  4.23751  , -1.5153179,
#        -1.984864 , -2.3014605], dtype=float32), 5: array([-2.5385182, -1.8340094,  5.3018003, -2.300047 , -2.4830546,
#        -3.9182942, -4.1020737], dtype=float32), 6: array([ 4.6960025, -1.5754321, -2.128346 , -1.9439157, -1.4775577,
#        -2.3848848, -1.6621677], dtype=float32), 7: array([-1.4039159, -0.984006 , -1.1746151,  5.3160777, -1.1898906,
#        -1.4094144, -2.235746 ], dtype=float32), 8: array([-2.0126526 , -1.808136  , -0.51644534,  4.850737  , -1.8166866 ,
#        -2.51076   , -2.2531102 ], dtype=float32), 9: array([-3.817764 , -2.7117827,  4.485781 , -2.085793 , -2.4144084,
#        -2.3890116, -1.1553817], dtype=float32), 10: array([ 5.8210464,  0.7760335, -4.434394 , -1.9607338, -2.8738437,
#        -3.0003037, -1.2906137], dtype=float32), 11: array([ 4.3049526 , -0.93016636, -2.9193459 , -0.92385525, -1.857393  ,
#        -2.1768277 , -1.0168824 ], dtype=float32), 12: array([-1.9517121 , -1.2170308 , -1.3179688 , -0.84055334,  5.1604238 ,
#        -1.3469858 , -1.1751746 ], dtype=float32), 13: array([-1.1020914 , -0.91295856, -1.0381063 ,  4.036779  , -0.646779  ,
#        -2.114821  , -2.0564415 ], dtype=float32), 14: array([-1.6899226 , -1.2890214 , -2.5317023 ,  4.861232  , -0.51682234,
#        -2.248768  , -2.4997506 ], dtype=float32), 15: array([-2.2437575, -1.3848102, -1.3967493,  5.233182 , -1.5592198,
#        -2.582934 , -2.700587 ], dtype=float32), 16: array([-1.4482762, -2.5929508,  5.0708923, -2.9616785, -1.8971324,
#        -3.4187346, -2.5735183], dtype=float32), 17: array([-1.647839 , -1.5631776, -1.1201077,  6.015984 , -1.0198388,
#        -2.4938583, -2.6682208], dtype=float32), 18: array([-1.6658275,  5.1943016, -1.6960077, -2.6105008, -3.137811 ,
#        -1.7168025,  5.429437 ], dtype=float32), 88: array([ 3.674476 , -5.840472 , -5.1663694, -5.6008   , -4.8344126,
#        -0.6892414, -2.8195043], dtype=float32), 89: array([-3.601491 , -3.734429 , -2.6966524, -1.5650363,  6.933189 ,
#        -1.854584 , -1.5304508], dtype=float32), 90: array([-3.486624 , -1.9958498,  4.9934506, -2.40877  , -3.042644 ,
#        -1.7602906, -2.937981 ], dtype=float32), 91: array([-1.7949855, -1.9144477, -1.540854 , -0.3036857,  5.9297547,
#        -3.7286682, -2.322376 ], dtype=float32), 92: array([-3.2586071, -2.8645554, -1.0226095, -3.1993341, -3.698023 ,
#        -2.4196157,  5.6170697], dtype=float32), 93: array([-0.95939255, -2.8566878 , -2.750987  , -3.2742858 , -2.423867  ,
#        -1.3344326 ,  4.0795026 ], dtype=float32), 94: array([ 5.334385  , -3.944759  , -3.601582  , -1.596736  ,  0.18909985,
#        -4.531498  , -1.8415602 ], dtype=float32), 95: array([ 6.628965 , -3.5095031, -5.002642 , -4.068701 , -2.9261982,
#        -3.7742736, -1.4566525], dtype=float32), 96: array([-3.4437714, -3.1565964, -1.9992766, -3.8326697, -2.6053894,
#        -1.0185901,  5.5798554], dtype=float32), 97: array([-3.1368258, -2.4252522, -2.534576 , -2.4092317, -2.0825577,
#         5.1369934, -2.2653275], dtype=float32), 98: array([ 5.301172 , -1.6597135, -2.3193605, -1.9642138, -1.8115108,
#        -1.8358424, -1.209146 ], dtype=float32), 99: array([-3.3287227, -3.6032157, -2.539305 , -3.943727 , -2.7478514,
#        -3.0067575,  7.1033916], dtype=float32), 100: array([ 4.877193 , -1.1868737, -1.9299443, -1.9161791, -1.9620683,
#        -2.2958362, -1.5044937], dtype=float32), 101: array([-3.4714313 , -1.4590106 ,  4.363245  , -0.12779158, -3.1903753 ,
#        -2.6428747 , -3.0290875 ], dtype=float32), 102: array([-1.784595  ,  4.3750243 , -3.0812118 , -1.6320101 , -3.415717  ,
#        -0.97853225, -3.0056348 ], dtype=float32), 103: array([-1.8177006,  5.053127 , -1.702024 , -2.75884  , -3.3373578,
#        -1.8404099, -2.317189 ], dtype=float32), 104: array([-1.9604957,  6.959963 , -2.3293626, -1.9000635, -4.12843  ,
#        -2.4767725, -2.3188078], dtype=float32), 105: array([-2.2506068, -2.5096488,  5.130021 , -4.0011463, -3.047976 ,
#        -3.2469535, -2.0908606], dtype=float32), 106: array([-3.1431909 , -4.0079393 , -3.4767303 , -4.997114  , -3.9525259 ,
#        -0.07574483,  6.8717318 ], dtype=float32), 107: array([-5.558691 , -2.427419 , -1.6780179, -3.4216843, -2.4119737,
#         6.391135 , -3.0380442], dtype=float32), 108: array([-3.728105 , -2.6109583, -2.0121768, -1.3440468, -3.0819676,
#        -1.0911549,  4.727927 ], dtype=float32), 109: array([-4.930868 ,  6.804036 , -4.004556 , -3.530758 , -6.77822  ,
#        -1.6478419, -3.8849232], dtype=float32), 110: array([-5.90116  , -2.0351589,  5.942604 , -0.9871788, -3.0368335,
#        -1.2992176, -1.3811249], dtype=float32), 135: array([-1.6673923,  5.5963125, -2.8499408, -2.0277615, -1.6679225,
#        -1.7001377, -2.6144543], dtype=float32), 136: array([-1.1948545,  5.0426865, -1.4401889, -1.5420353, -2.7452917,
#        -1.7719223, -1.784109 ], dtype=float32), 137: array([-2.2977822,  6.615581 , -3.6423635, -2.2070556, -1.7416956,
#        -1.72344  , -3.0669823], dtype=float32), 138: array([-1.5430107,  4.088015 , -1.5307715, -1.1246139, -3.2361476,
#        -1.1760722, -1.1650704], dtype=float32), 139: array([-2.1865013,  6.5894084, -1.9975426, -3.093248 , -3.9915192,
#        -1.6820096, -2.8428776], dtype=float32), 140: array([-1.6920822 , -2.4151046 , -1.6564374 , -2.031537  ,  4.186752  ,
#        -1.4325656 , -0.25580853], dtype=float32), 141: array([-1.3674129 , -2.8818722 , -1.2627966 ,  0.85356176,  3.7322357 ,
#        -2.6860676 , -1.8703709 ], dtype=float32), 142: array([ 5.2743187, -1.5437446, -2.9151533, -2.1249037, -1.0717759,
#        -2.810915 , -1.3602043], dtype=float32), 143: array([-1.5953848 , -0.8039081 , -0.907047  ,  3.2771401 , -0.47901374,
#        -1.6358769 , -1.9478989 ], dtype=float32), 144: array([-2.171844 , -2.9810367, -1.899447 , -0.4602413, -2.4025228,
#        -1.436937 ,  2.9428043], dtype=float32), 145: array([-2.7387836, -3.2956002, -2.7850835, -0.5572075, -2.937449 ,
#        -1.1483732,  3.0014505], dtype=float32), 146: array([ 2.2867122 , -2.5493896 , -2.129832  ,  0.34403414, -0.60996526,
#        -2.9469113 , -1.3355694 ], dtype=float32), 147: array([-1.1876044 , -0.9233998 , -3.9367807 , -0.7387255 , -1.8722358 ,
#         0.29330975, -0.04948483], dtype=float32), 148: array([-2.8143158 , -0.88709855, -0.48465487, -0.99735326,  4.3601046 ,
#        -3.5450544 , -3.0532544 ], dtype=float32), 149: array([ 2.0396845 , -1.4678776 , -2.6949286 ,  0.03384656, -1.7934692 ,
#        -1.4420917 , -1.0601723 ], dtype=float32), 150: array([-2.2848065 , -1.3593242 , -1.7893269 ,  3.8627992 , -0.31327218,
#        -0.8760248 , -2.5891914 ], dtype=float32), 151: array([-0.7789309, -1.4559906, -1.708781 ,  0.9325609,  3.0125098,
#        -2.4445796, -1.4557258], dtype=float32), 152: array([-1.4893986 , -1.6770371 , -1.8089633 , -0.36308324,  4.378405  ,
#        -1.8348447 , -1.5349655 ], dtype=float32), 153: array([-1.8788891,  4.5513716, -1.655612 , -1.3449993, -3.3123138,
#        -1.5176286, -1.9434633], dtype=float32), 154: array([-3.4321272, -3.423655 ,  6.6262608, -2.6552734, -2.824964 ,
#        -3.679603 , -4.89541  ], dtype=float32), 155: array([-4.399738 , -2.3335905,  6.0875845, -2.7823114, -3.7188556,
#        -2.2388844, -3.6218843], dtype=float32), 156: array([-3.9989498, -2.3007839,  5.7206926, -2.6399293, -3.5255682,
#        -2.134471 , -3.350364 ], dtype=float32), 157: array([-1.6024439, -0.6339955, -0.7568522,  2.9528446, -1.148459 ,
#        -1.7467847, -1.6887172], dtype=float32), 158: array([-1.6324205, -1.3124982, -1.9527571,  3.4622989,  0.4028268,
#        -1.9986755, -2.1723185], dtype=float32), 159: array([-1.8885751 , -1.2185427 , -1.6645074 ,  4.1948743 ,  0.07434928,
#        -2.5315337 , -2.0680318 ], dtype=float32), 160: array([-0.8988116 , -1.2146531 , -0.91758376,  0.32449067, -0.6132261 ,
#        -2.7297192 , -0.9220299 ], dtype=float32), 161: array([-1.1532009e-03, -1.9899983e+00, -1.1141365e+00, -1.4038508e+00,
#        -5.3920108e-01, -2.1307166e+00,  1.2456059e+00], dtype=float32), 162: array([ 0.99497634, -3.6125228 , -1.6153836 , -2.4584727 ,  1.5822012 ,
#        -2.394697  , -0.79917467], dtype=float32), 163: array([-8.031101 , -4.060766 , -1.4246054, -2.6210966, -2.6360152,
#         7.268208 , -2.129808 ], dtype=float32), 164: array([ 0.21840976, -2.3697479 , -1.4043174 , -0.37659964,  0.8219643 ,
#        -1.6751411 , -0.9448323 ], dtype=float32), 165: array([-2.0385935 , -0.07726617, -0.91606927,  4.835208  , -0.6467466 ,
#        -2.3165734 , -3.5739655 ], dtype=float32), 166: array([-3.758942  , -2.5340571 , -3.257495  , -0.74105567,  1.1254134 ,
#         1.2224822 , -1.3909223 ], dtype=float32), 167: array([ 2.3480732 , -0.23264661, -1.4344568 , -0.32250583, -2.804892  ,
#        -3.209984  , -2.3387043 ], dtype=float32), 168: array([ 1.7039056 , -0.77507436, -1.0403271 , -0.33582857, -2.7349145 ,
#        -2.369531  , -1.8111901 ], dtype=float32), 169: array([-1.291773  , -0.5966676 , -1.3076673 ,  3.6478376 , -0.08422467,
#        -2.3808005 , -2.3890188 ], dtype=float32), 170: array([-2.217195 , -1.7219026,  3.6306782, -2.2212534, -2.5041165,
#        -1.8999987, -1.8853474], dtype=float32), 171: array([-2.4718294 , -2.417865  , -2.006469  ,  2.9452157 , -0.5896651 ,
#        -0.87410563, -1.9862549 ], dtype=float32), 172: array([ 0.61623394, -1.0989838 , -1.3483555 , -1.4517539 ,  2.5064337 ,
#        -3.4917014 , -1.299523  ], dtype=float32), 173: array([-2.9400785 , -0.4988299 ,  4.7518644 , -0.41484675, -2.3281574 ,
#        -3.003201  , -4.324602  ], dtype=float32), 174: array([-3.0623581, -2.297184 ,  4.9759374, -2.628759 , -3.489824 ,
#        -3.3262055, -1.3211879], dtype=float32), 175: array([-2.656105 , -2.8496187, -2.7906687, -4.10418  , -3.5996034,
#        -1.8791485,  5.22681  ], dtype=float32), 176: array([-1.3360885 ,  0.36877707, -2.162434  , -1.4525439 , -1.649914  ,
#         0.3892849 , -0.5908954 ], dtype=float32), 177: array([-0.65923375, -1.6841474 , -0.15671262, -4.3137884 ,  3.163425  ,
#        -2.859178  , -1.5423601 ], dtype=float32), 178: array([-2.1829877 ,  1.0564355 , -1.0138493 ,  3.5113149 , -0.50395435,
#        -1.3147858 , -3.1052892 ], dtype=float32), 179: array([-1.6852838 , -1.2525305 , -1.1333606 ,  2.1070824 , -0.57147425,
#        -1.0312078 , -1.724169  ], dtype=float32), 180: array([-3.2927763, -2.3241193, -2.3062842,  5.844505 , -0.571725 ,
#        -3.0745325, -2.9381483], dtype=float32), 181: array([-0.75408006, -2.491536  , -2.4471345 , -2.3015494 , -1.5827746 ,
#        -1.6776645 ,  3.5083106 ], dtype=float32), 182: array([-2.357631  , -0.48928586, -1.3223953 ,  3.7648368 , -0.73820907,
#        -1.1683629 , -1.950034  ], dtype=float32), 183: array([-2.459501 , -0.6454184, -1.4346786,  3.6691947, -1.0478127,
#        -1.3052785, -2.080027 ], dtype=float32), 184: array([-3.2875366 ,  1.3844125 , -1.6955812 ,  0.81790495, -2.4483798 ,
#        -0.45013875, -3.3415897 ], dtype=float32), 185: array([-0.5153479 , -1.110258  , -0.37786075,  2.3933797 , -0.17130965,
#        -2.6496043 , -2.023734  ], dtype=float32), 186: array([ 1.1429468, -1.3275722, -2.3426476,  2.3920636, -0.3117327,
#        -3.6038337, -2.5412738], dtype=float32), 187: array([-1.5040141, -1.6627563,  1.684438 , -2.1685112,  2.7412117,
#        -5.168904 , -2.3592181], dtype=float32), 188: array([-2.5916045, -2.6390681,  4.104889 , -1.8362297, -2.5048602,
#        -1.7310445, -2.0470805], dtype=float32), 189: array([-3.6208348, -1.1036309,  4.681288 , -2.6419673, -4.112687 ,
#        -2.1331067, -2.1381264], dtype=float32), 190: array([-2.7285197, -2.3858588, -1.7936406, -3.873685 , -2.11007  ,
#        -2.0287464,  4.4476967], dtype=float32), 191: array([-0.6621904 ,  0.29453808, -1.483849  , -0.18509328, -2.6889307 ,
#        -1.9021508 , -2.0406382 ], dtype=float32), 192: array([-0.21197669, -1.3434118 ,  1.282985  , -2.11315   ,  0.63665366,
#        -2.0427976 , -1.6221656 ], dtype=float32), 193: array([-2.2078288, -2.3567822, -2.9569726, -2.6448917, -2.9738925,
#         4.6514745, -1.0983938], dtype=float32), 194: array([-3.0578308, -2.8228734, -2.294108 ,  0.0862931,  6.435878 ,
#        -2.9089384, -2.1322622], dtype=float32), 195: array([ 3.4397485 , -2.2669501 , -1.2938213 , -1.3550119 , -0.9438147 ,
#        -2.4884868 , -0.97368896], dtype=float32), 196: array([-1.5177877, -1.3622739, -1.7538018,  0.2979958,  4.4892297,
#        -2.6798816, -2.1617892], dtype=float32), 197: array([-1.9573205 , -1.2816453 , -1.7273481 ,  2.480754  , -0.8129687 ,
#        -0.42530167, -2.1115935 ], dtype=float32), 198: array([-0.78419435, -1.5578237 , -1.350738  , -1.8642911 ,  5.4010897 ,
#        -2.630908  , -1.001991  ], dtype=float32), 199: array([ 1.6980152 , -2.1011705 , -1.320704  , -0.08814037,  2.1758072 ,
#        -2.8047068 , -2.1839404 ], dtype=float32), 200: array([-2.359447 ,  0.6190991, -2.1527407,  2.320603 ,  0.1799837,
#        -1.3561275, -2.2495153], dtype=float32), 201: array([-2.020783  , -1.7557328 , -1.1817565 ,  4.2907043 , -0.47272593,
#        -2.6713996 , -2.1189284 ], dtype=float32), 224: array([-0.84709144, -0.76097256, -1.8969619 ,  2.2791018 ,  1.1302369 ,
#        -1.7610738 , -1.7599787 ], dtype=float32), 225: array([-1.5202104, -3.2079215, -1.6251373, -1.2781601, -3.0828514,
#        -2.3117151,  1.720976 ], dtype=float32), 226: array([-1.2628978 , -1.4327655 , -0.8270381 ,  1.8223041 , -0.15128434,
#        -1.5908895 , -0.3948189 ], dtype=float32), 227: array([-3.750666 , -1.204721 ,  4.2549796, -2.5591998, -2.1624002,
#        -2.6340928, -1.7285113], dtype=float32), 228: array([-3.464922  , -2.4166949 ,  5.0598307 ,  0.99203897, -3.348299  ,
#        -3.5749307 , -4.8739314 ], dtype=float32), 229: array([-2.0220928 , -1.2162818 ,  0.12898259,  3.9022417 , -1.9444902 ,
#        -4.149281  , -2.681686  ], dtype=float32), 230: array([-1.8849456 , -1.1969379 , -1.121331  ,  5.601828  , -0.69585866,
#        -3.5844371 , -2.9547439 ], dtype=float32), 231: array([-3.4663095 , -2.3816035 , -2.6590106 ,  1.3844072 , -1.2435482 ,
#        -1.2613914 , -0.43513852], dtype=float32), 232: array([-2.0271282 , -1.2949485 , -1.0067558 ,  3.4323587 , -0.54526895,
#        -1.9387378 , -1.759333  ], dtype=float32), 233: array([-4.5442414, -1.1657941, -1.7507105, -2.4142337, -1.8858368,
#         4.5281625, -2.0361419], dtype=float32), 234: array([-1.3412982,  3.0618844, -1.2974722, -2.5380073, -4.118618 ,
#        -0.1612764, -1.8451585], dtype=float32), 235: array([-1.5482244 , -0.47421476, -0.60510314,  2.6449103 , -1.4157774 ,
#        -1.6710542 , -1.5654169 ], dtype=float32), 236: array([-2.9004297 ,  5.2646036 , -2.3185039 , -0.02590975, -5.2485704 ,
#        -1.9484044 , -2.3715315 ], dtype=float32), 237: array([-3.658241  , -1.0679607 , -0.29802018,  4.25495   , -0.10683119,
#        -1.3533998 , -2.3663738 ], dtype=float32), 238: array([ 0.15450202, -0.45749173, -4.5770745 , -2.189859  , -4.113579  ,
#         3.9372225 , -2.3998861 ], dtype=float32), 239: array([ 4.419344  , -2.309172  , -4.166764  , -0.07468778, -2.2995074 ,
#        -4.2772956 , -2.1855292 ], dtype=float32), 240: array([ 0.97059345, -1.2066164 , -1.4710689 , -1.5062925 ,  2.484408  ,
#        -3.5491347 , -1.1232355 ], dtype=float32), 241: array([-2.074515 , -1.9235069, -0.6601014, -2.4368563, -2.3978546,
#         1.7956171, -0.8914711], dtype=float32), 242: array([ 2.2463465 , -2.5789144 , -2.648008  , -2.9107652 , -2.076289  ,
#        -0.33760095,  0.16733481], dtype=float32), 243: array([-0.92181444, -2.9921393 , -2.7429855 , -0.01159585,  6.10882   ,
#        -3.2805002 , -2.2915764 ], dtype=float32), 244: array([-2.4982984 , -0.17155261,  2.9026537 , -2.5935936 , -2.949115  ,
#        -2.161803  , -1.8091824 ], dtype=float32), 245: array([-2.1525073 , -1.8709953 , -1.9534011 , -1.2600423 ,  3.5838401 ,
#        -1.1148463 , -0.55013776], dtype=float32), 246: array([-2.95234  , -2.6741977,  5.4778733, -2.5471592, -2.3871691,
#        -2.7394109, -3.1195922], dtype=float32), 247: array([ 1.0245512 , -3.683527  , -0.47274092, -1.7705454 ,  4.1562214 ,
#        -3.788878  , -1.6590548 ], dtype=float32), 248: array([-0.04043658, -1.7451856 , -0.6947712 ,  1.1761984 ,  1.0265291 ,
#        -1.6513937 , -1.6317306 ], dtype=float32), 249: array([-2.5019178, -2.8169894, -2.0005555, -2.791098 , -1.7559612,
#         3.7271516, -1.924149 ], dtype=float32), 250: array([-2.973871  ,  6.389664  , -0.63519657, -1.7726864 , -2.574533  ,
#        -1.8565589 , -4.532365  ], dtype=float32), 251: array([-1.1694349 , -1.312266  , -1.2802844 ,  3.452938  ,  0.06200603,
#        -2.8113754 , -3.1642137 ], dtype=float32), 252: array([-0.5072112, -1.2125697, -2.8133693, -3.1144214, -3.1954086,
#         0.7650663,  0.6094788], dtype=float32), 253: array([-1.1219096, -1.087739 , -0.857083 ,  2.238078 ,  0.5758065,
#        -2.0971215, -2.3485925], dtype=float32), 254: array([ 0.24303338, -1.9206113 , -0.57941675, -0.7824302 ,  1.855731  ,
#        -2.2414908 , -1.7321758 ], dtype=float32), 255: array([-1.1644242 , -2.060893  , -3.0453665 , -0.4482629 , -0.12059915,
#        -1.4421612 ,  0.7478218 ], dtype=float32), 256: array([ 0.40545297, -1.1675034 ,  0.24628896, -0.88283193,  0.5477515 ,
#        -2.8420234 , -1.6322327 ], dtype=float32), 257: array([ 4.9378386 , -1.9449991 , -3.453504  , -1.856341  , -1.4390655 ,
#        -2.368742  , -0.54475343], dtype=float32), 258: array([-3.1877332, -2.668779 , -2.0350935, -1.8439404,  6.5913377,
#        -1.526005 , -1.7115014], dtype=float32), 259: array([-4.8469477, -1.6554145, -2.4741201, -3.2319179, -4.953042 ,
#         5.550083 , -2.1949599], dtype=float32), 260: array([-0.5394033, -2.1612475,  2.9732358, -1.778864 , -1.0058224,
#        -1.8079715, -1.9986324], dtype=float32), 261: array([-1.5534524, -0.3857405, -1.5426311,  2.6277022, -1.6482508,
#        -1.7841905, -2.281713 ], dtype=float32), 262: array([-2.8736172 , -3.1502814 , -1.8914115 , -2.041865  , -1.425899  ,
#         0.09391008,  2.9632163 ], dtype=float32), 263: array([-2.3495986, -2.387414 ,  3.8648062, -2.105795 , -2.2508466,
#        -1.9101036, -2.23792  ], dtype=float32), 264: array([-2.0384018 , -0.57685405, -2.6824722 , -1.3611331 , -2.8170817 ,
#         3.1743445 , -2.4484053 ], dtype=float32), 265: array([-1.832233 , -1.6739385, -0.6328868, -1.3244189, -1.3273573,
#         1.5747707, -0.9394254], dtype=float32), 266: array([-0.5994407 , -1.7682875 , -2.4939508 , -0.76981074, -1.8059373 ,
#         0.10066198, -1.0808663 ], dtype=float32), 267: array([ 0.6459324 , -2.639004  ,  0.9033821 , -2.5998588 ,  0.01256713,
#        -4.3547072 , -1.0052885 ], dtype=float32), 268: array([-1.6256847 ,  0.05090175,  1.672251  , -2.0772467 , -1.8814328 ,
#        -1.4221947 , -1.5673788 ], dtype=float32), 269: array([-1.6041048, -2.1635919, -1.4575005,  6.5091634, -2.5320392,
#        -3.8887832, -3.0666723], dtype=float32), 270: array([ 2.5346138 , -2.415078  , -3.105174  , -3.05434   , -2.259438  ,
#        -0.07873667, -0.27514046], dtype=float32), 271: array([-3.4090989 , -1.7807529 , -3.1522107 , -0.22650494,  3.0961518 ,
#        -0.15087092, -1.8807063 ], dtype=float32), 272: array([ 2.8399827 , -3.2268634 , -2.3412735 , -1.2961823 , -1.6867685 ,
#        -0.69642884, -1.0508978 ], dtype=float32), 273: array([-0.9050075 , -2.1654935 , -1.0576434 ,  0.7231003 , -1.7563436 ,
#        -1.1763804 , -0.33431634], dtype=float32), 274: array([ 0.65267956, -0.65830964, -2.0828772 , -1.8003185 , -2.2930527 ,
#        -1.0792415 , -0.36408925], dtype=float32), 275: array([ 0.49091095, -3.2363467 , -1.8569117 , -0.363434  ,  2.2039044 ,
#        -1.0852181 , -1.5611087 ], dtype=float32), 276: array([ 2.816927 , -1.914973 , -2.9284859, -1.463264 , -1.8110125,
#        -0.6044133, -0.5192337], dtype=float32), 277: array([-0.28838485, -1.0101347 , -2.4920762 , -0.7769847 , -0.7120902 ,
#        -1.0010705 , -0.5912034 ], dtype=float32), 278: array([-0.5388709 , -0.9064864 , -0.13801618, -0.3122899 ,  1.3261826 ,
#        -1.5659281 , -0.9806728 ], dtype=float32), 279: array([ 3.032538  , -3.3829794 , -4.9389863 , -2.9868789 , -4.305643  ,
#        -1.1984928 ,  0.30687535], dtype=float32), 280: array([ 0.61961615, -1.5435534 , -2.32543   , -1.9921862 , -0.1821844 ,
#        -1.6285026 ,  1.4353017 ], dtype=float32), 281: array([-4.1407914 , -1.8335966 ,  0.34125817,  6.6792555 , -3.6731884 ,
#        -3.6120899 , -3.8714979 ], dtype=float32), 282: array([-3.5440118, -1.5970559, -2.2601616, -2.5600467, -2.2484746,
#         5.4086328, -2.1867719], dtype=float32), 283: array([-1.1995617 , -0.11097656, -1.5961885 , -0.7779441 ,  2.6204903 ,
#        -2.463437  , -1.4915776 ], dtype=float32), 284: array([-3.2082908, -3.0355546, -2.2844458, -2.168252 ,  5.514596 ,
#        -1.2681904, -0.6004899], dtype=float32), 285: array([-0.31634337, -2.6447458 , -2.7959285 , -0.55776453, -2.3372896 ,
#        -0.5365046 ,  1.2924721 ], dtype=float32), 286: array([-0.9582405 , -0.6298308 , -1.9546974 ,  0.02300578,  3.708802  ,
#        -2.5413835 , -2.2752218 ], dtype=float32), 287: array([ 1.1461047 ,  0.9642745 , -4.2250466 , -0.93054706, -3.660786  ,
#         0.98021275, -1.0480478 ], dtype=float32), 288: array([ 7.6838374e-01, -3.9023499e+00, -8.3339983e-01,  1.0193381e-01,
#        -2.5862532e+00, -2.6544442e+00, -1.3246387e-03], dtype=float32), 289: array([-2.0943308,  0.3565519,  1.4491744, -2.1482863, -2.4947748,
#        -1.208358 , -1.8828545], dtype=float32), 290: array([-3.1688356 , -1.3236818 ,  4.5658064 ,  0.15908271, -2.255855  ,
#        -3.1298935 , -3.52857   ], dtype=float32), 291: array([-0.12459813, -0.30112258, -1.0114398 , -1.6617547 ,  2.2644763 ,
#        -2.1197517 , -1.1954769 ], dtype=float32), 292: array([ 0.41348398, -2.8087745 , -0.74701965,  0.00583327, -2.7155504 ,
#        -1.9151809 , -0.03223357], dtype=float32), 293: array([-0.76460624, -2.8000116 , -0.53282475,  1.7156667 ,  2.1387806 ,
#        -2.4254863 , -2.076245  ], dtype=float32), 294: array([-0.24342959,  2.1312351 , -2.7220054 , -1.3676531 , -2.2037418 ,
#        -0.68393064, -0.8579771 ], dtype=float32), 295: array([-0.3098086 , -1.4774907 , -0.8105692 ,  2.6949368 ,  0.28848803,
#        -3.559359  , -1.7106141 ], dtype=float32), 296: array([-2.2004187, -2.4341722,  4.2477794, -2.0899825, -1.983911 ,
#        -1.8901501, -2.4264472], dtype=float32), 297: array([-1.0337884 , -1.4365948 , -0.95034623,  3.7948833 , -0.77819055,
#        -2.733273  , -2.426635  ], dtype=float32), 298: array([-1.5681463 , -1.4206454 , -0.64038664,  3.3507009 , -1.1580777 ,
#        -2.24963   , -1.8476021 ], dtype=float32), 299: array([-2.410465  , -0.86709774, -2.2600272 , -0.42378613,  1.8062165 ,
#        -0.37587386, -2.0692394 ], dtype=float32), 300: array([ 2.954601 , -2.3842874, -2.9789736, -2.43993  , -3.114626 ,
#         0.9837132, -1.217445 ], dtype=float32), 301: array([-1.8723907, -2.0021708,  4.3232126, -1.4268807, -1.7997272,
#        -2.473112 , -2.9006371], dtype=float32), 302: array([-1.4106572,  5.1456327, -1.5327992, -2.239616 , -2.2590904,
#        -2.1618485, -2.963498 ], dtype=float32), 303: array([-1.6887457,  2.4938982, -1.0065322, -1.7755332, -1.0930867,
#        -1.4243288, -2.0518668], dtype=float32), 304: array([ 1.7878627 , -0.55548656, -3.1631067 , -1.0546782 , -2.3468952 ,
#        -1.1583264 , -0.65047747], dtype=float32), 305: array([ 3.3893912, -1.649581 , -1.9045031, -0.5346437, -1.8763297,
#        -2.1128213, -0.90588  ], dtype=float32), 306: array([ -5.650451 ,  11.73371  ,  -6.569098 ,  -3.5378556, -11.645281 ,
#         -4.980627 ,  -5.8153205], dtype=float32), 307: array([-2.008454 , -2.0118847, -0.8275164, -2.3430786, -1.9793739,
#        -2.074768 ,  3.9913995], dtype=float32), 308: array([-1.5557908,  4.943897 , -2.0092156, -2.0268672, -2.9121447,
#        -1.749272 , -2.5023794], dtype=float32), 309: array([-1.1772262, -0.6952771, -1.5444331,  1.660127 ,  1.1537836,
#        -1.8046188, -2.1783626], dtype=float32), 310: array([-3.0571456, -2.159415 , -3.7553139,  9.049409 , -1.0341136,
#        -3.5652528, -3.9974813], dtype=float32), 311: array([-4.399371 , -3.464972 , -1.3870485,  2.9280515,  1.7179523,
#        -3.8403873, -1.8104093], dtype=float32), 312: array([-2.2625082 , -0.05557766,  2.4047098 , -2.9224334 , -2.7098458 ,
#        -2.2761126 , -1.2111952 ], dtype=float32), 313: array([-2.8301942, -1.1060281, -1.1881208,  5.075442 , -1.0287645,
#        -2.1631315, -1.6313791], dtype=float32), 314: array([-0.89799523,  0.9870274 ,  0.09439516,  0.0514648 , -1.0951481 ,
#        -2.265655  , -1.9605522 ], dtype=float32), 315: array([ 6.715949 , -2.2689097, -3.7314994, -1.1395156, -2.4162924,
#        -3.456729 , -1.4368246], dtype=float32), 316: array([-2.89803   , -1.8075645 , -1.2981155 ,  5.694491  , -0.45209652,
#        -2.970859  , -3.2708685 ], dtype=float32), 317: array([-1.6681728 ,  0.9702952 , -1.0655844 , -2.3128266 ,  1.0084212 ,
#        -0.37130964, -1.696368  ], dtype=float32), 318: array([-1.9410679 ,  2.3743556 , -1.6551335 ,  0.28499246, -2.7227595 ,
#        -0.76598305, -1.8414047 ], dtype=float32), 319: array([-1.2143438 , -0.53114027,  2.985663  , -0.06585562, -2.3887494 ,
#        -3.022783  , -3.2875593 ], dtype=float32), 320: array([-0.75471705, -1.2654613 , -0.8305764 ,  0.31456947,  2.430043  ,
#        -2.495511  , -2.401747  ], dtype=float32), 321: array([ 0.58687747, -1.6584041 , -1.7985408 ,  4.9135766 , -2.6444035 ,
#        -3.1700022 , -2.4107025 ], dtype=float32), 322: array([-2.442269 , -2.1741414,  4.3610597,  1.6426886, -2.832418 ,
#        -2.9259443, -4.5084524], dtype=float32), 323: array([-0.37363625, -3.2828062 , -2.2958026 , -2.5670872 ,  2.0418692 ,
#        -1.8755214 , -0.17373316], dtype=float32), 324: array([ 0.25120127, -1.8994865 , -2.5316105 , -2.068884  , -1.2657619 ,
#        -0.2170447 , -0.62075365], dtype=float32), 325: array([-0.35112095, -1.7096517 , -1.181489  , -2.3688836 ,  2.5389082 ,
#        -2.2657447 , -1.2968262 ], dtype=float32), 326: array([-1.860985 , -1.512808 ,  4.135084 , -1.6338749, -1.642874 ,
#        -2.252805 , -2.8080642], dtype=float32), 327: array([-2.6884341 , -1.3384321 , -0.47791955,  7.378154  , -1.7686887 ,
#        -3.335071  , -4.061402  ], dtype=float32), 328: array([-2.782866 , -2.0350502,  4.151315 , -0.6620101, -1.5839527,
#        -2.6446447, -2.6349275], dtype=float32), 329: array([-1.1520612,  3.294675 , -1.6595998, -1.566099 , -3.2493656,
#        -1.6301057, -1.4342132], dtype=float32), 330: array([-1.5430619 , -0.20037025, -1.1120317 , -1.0156164 ,  2.9391398 ,
#        -2.3387437 , -1.6761451 ], dtype=float32), 331: array([ 1.8295622, -2.2977052, -2.4720976, -2.7429724, -2.6821573,
#        -1.3684212,  1.6582541], dtype=float32), 332: array([-1.4452237 , -1.381048  , -1.9704893 ,  0.32677126,  4.079093  ,
#        -3.621995  , -1.698292  ], dtype=float32), 333: array([-1.935086  , -1.6434262 ,  2.56323   ,  0.69073904, -0.88537246,
#        -3.312026  , -2.3438625 ], dtype=float32), 334: array([ 2.5795698 , -1.6121085 , -2.6772485 , -2.1075923 , -1.0426037 ,
#        -1.2470461 , -0.21739991], dtype=float32), 335: array([-0.93953776, -0.68256783, -0.66214246,  2.107952  , -0.14663714,
#        -1.5965574 , -1.4773657 ], dtype=float32), 336: array([-0.15776433, -0.81939256, -1.6493814 ,  3.4721775 ,  0.09328756,
#        -2.0410516 , -1.7796731 ], dtype=float32), 337: array([-2.3324525 ,  0.00539273,  2.6266997 , -1.8710399 , -2.8627768 ,
#        -1.8713869 , -2.0122235 ], dtype=float32), 338: array([-1.0372769 , -1.4996817 , -1.461997  ,  2.197894  , -0.23736256,
#        -1.3646462 , -2.428295  ], dtype=float32), 339: array([ 0.21701743, -1.760946  ,  0.10376787, -1.3194544 ,  0.5295314 ,
#        -2.440285  , -3.2692573 ], dtype=float32), 340: array([-1.4847519 , -2.002059  , -1.320992  , -1.1147473 ,  3.361582  ,
#        -1.4012438 , -0.60469323], dtype=float32), 341: array([-4.246176  ,  0.12299239,  3.8261826 ,  0.69900966, -2.2301345 ,
#        -3.029756  , -3.509352  ], dtype=float32), 342: array([-1.3123164 ,  0.09074915, -1.5128386 , -2.3197064 , -2.556526  ,
#         0.18607105,  0.03824985], dtype=float32), 343: array([-2.2649996 , -1.9457741 , -1.220109  ,  2.9875345 ,  0.34834293,
#        -2.3740292 , -1.7127428 ], dtype=float32), 344: array([-3.8508003, -1.3446001, -2.0946355, -2.4436378, -1.1415434,
#         3.4080791, -2.8873951], dtype=float32), 345: array([-2.882236  , -0.01886057,  0.0986498 ,  1.9651297 ,  0.5336866 ,
#        -2.1514964 , -2.2378461 ], dtype=float32), 346: array([-2.6886022, -2.0712395,  4.7199535, -2.7954516, -1.9082735,
#        -2.713894 , -2.2223384], dtype=float32), 347: array([ 5.8640327, -1.9332253, -3.7390928, -1.3682857, -0.8614581,
#        -3.3166883, -1.1899809], dtype=float32), 348: array([-1.7797296, -1.707205 , -1.4671798, -1.504955 ,  5.1582575,
#        -2.6821437, -2.6044874], dtype=float32), 349: array([-0.22852911, -1.3316126 , -4.0413823 , -2.568912  , -2.3193207 ,
#         1.7426045 , -1.0164354 ], dtype=float32), 350: array([-2.1141794,  6.42924  , -2.9230814, -2.7314463, -4.530749 ,
#        -2.683188 , -3.5450037], dtype=float32), 351: array([ 0.47280502, -1.1670073 , -1.0881441 ,  2.4021935 , -0.6825648 ,
#        -2.2343826 , -1.5025978 ], dtype=float32), 352: array([-1.8098147 , -0.96563643, -1.1228454 ,  4.4576364 ,  0.23491934,
#        -2.1272779 , -2.3344076 ], dtype=float32), 353: array([-1.5452719, -1.6898034,  2.7314003, -2.5119705, -0.6640164,
#        -2.4834957, -3.2186787], dtype=float32), 354: array([ 0.04992411, -3.2721865 , -3.395012  , -4.185377  , -2.5706933 ,
#        -2.043266  ,  4.2851644 ], dtype=float32), 355: array([-0.90766776, -4.4651814 ,  1.8813045 , -5.567     , -3.55934   ,
#        -1.4299634 , -0.38231874], dtype=float32), 356: array([-0.07712184, -1.7940818 , -2.9380667 , -2.6522398 , -1.0738552 ,
#         0.5198547 , -1.5919781 ], dtype=float32), 357: array([-3.0066607, -1.3569937,  4.662734 , -2.3212059, -2.4875176,
#        -2.4028654, -2.3159122], dtype=float32), 358: array([-2.156366 , -1.4274731,  5.3152018, -2.3330936, -2.2221663,
#        -3.1794236, -2.644139 ], dtype=float32), 359: array([-2.4254634,  0.8499006,  1.6426506, -2.7049112, -3.6409929,
#        -1.433778 , -1.701818 ], dtype=float32), 360: array([-4.05883  , -1.2683451, -2.5887134, -0.9624726, -2.0134811,
#         3.0210166, -0.7674465], dtype=float32), 361: array([-0.945577 , -1.8013582,  1.160255 , -2.9029188,  1.094812 ,
#        -2.7132869, -1.2507553], dtype=float32), 362: array([ 0.551609 , -1.722507 , -1.0282421,  0.267977 ,  1.9529543,
#        -1.8014848, -1.4430194], dtype=float32), 363: array([-4.2631125, -1.8843122,  3.988449 , -1.2991314, -1.271704 ,
#        -1.974922 , -2.3714616], dtype=float32), 364: array([-2.6586626, -3.9312856,  6.8173933, -3.1259117, -3.6894877,
#        -4.2507973, -4.2056794], dtype=float32), 365: array([-0.6228134, -2.6900847,  2.8642492, -2.0653572, -1.3826015,
#        -1.5686044, -2.1713862], dtype=float32), 366: array([-0.7850238 , -1.3054757 , -0.643256  , -0.6323035 , -0.40901244,
#        -2.2037241 ,  0.0319653 ], dtype=float32), 367: array([-2.0312798,  0.4046195,  1.9401345, -2.4961576, -2.4003747,
#        -1.7474344, -1.8368732], dtype=float32), 368: array([-2.898927 , -1.5881097, -0.2003283, -3.182644 ,  5.0806203,
#        -2.9897442, -2.1409242], dtype=float32), 369: array([-0.06655021, -2.0811272 , -1.147805  , -0.55310756,  2.0173903 ,
#        -1.4687648 , -1.0142081 ], dtype=float32), 370: array([-4.059773 , -1.3556926, -3.899479 , -2.7389512, -4.105266 ,
#         6.7971444, -2.596689 ], dtype=float32), 371: array([-4.4407835, -2.3544424, -3.430214 , -2.3929515, -4.0587654,
#         6.3180847, -2.243348 ], dtype=float32), 372: array([-1.6003435 ,  2.8384607 , -0.4724119 , -0.23773307, -3.0428154 ,
#        -2.3494458 , -3.2404785 ], dtype=float32), 373: array([ 3.922695 , -1.4784961, -1.6185584, -2.0972066, -0.512855 ,
#        -2.0854597, -1.8721098], dtype=float32), 374: array([-1.628357  , -3.2373369 , -1.5517428 ,  1.6092124 , -2.595567  ,
#        -1.2435063 , -0.96419704], dtype=float32), 375: array([-2.0781302, -3.229075 , -1.5681376, -1.406061 ,  6.23548  ,
#        -2.68363  , -0.7159969], dtype=float32), 376: array([-1.5565534 , -1.7385545 ,  0.10937373, -2.2144423 , -3.2664368 ,
#        -1.2817162 , -0.44568586], dtype=float32), 377: array([-0.20985748, -2.2377813 , -1.7252543 ,  1.4678036 ,  2.8669071 ,
#        -3.2273839 , -2.069388  ], dtype=float32), 378: array([-2.6466296 ,  0.01925866,  0.3208284 , -1.6034801 ,  3.2600691 ,
#        -2.8331554 , -2.450387  ], dtype=float32), 379: array([-4.7933507, -2.885653 , -3.8730874, -2.4818096, -3.6082566,
#         7.2786274, -2.4634602], dtype=float32), 380: array([-1.7694519 , -2.347928  ,  0.28597948, -0.39224708,  0.43896025,
#        -1.8722131 , -0.86541677], dtype=float32), 381: array([-1.1860473 , -0.85257196, -0.7074597 , -1.4584191 ,  3.457863  ,
#        -2.3333468 , -2.2444806 ], dtype=float32), 382: array([-0.64238435, -0.9147532 , -1.5787904 ,  0.1582092 ,  0.39809373,
#        -0.8981568 , -1.4453896 ], dtype=float32), 383: array([-0.9519905, -1.1309884, -1.7659566,  1.5686818,  1.4400907,
#        -1.8386061, -2.1712124], dtype=float32), 384: array([-0.8336389,  2.863535 , -0.7468331, -1.805892 , -1.8020005,
#        -1.8212107, -1.4121912], dtype=float32), 385: array([-0.26204264, -2.226208  , -1.1999385 , -0.215179  ,  1.8437927 ,
#        -1.7900662 , -1.1332641 ], dtype=float32), 386: array([-1.6012313 , -0.43928152, -1.204246  ,  3.4792256 , -0.5372518 ,
#        -2.0632381 , -2.296591  ], dtype=float32), 387: array([-3.4831402 , -1.7778723 , -1.311547  ,  0.6224865 ,  0.44736084,
#        -1.266219  , -0.36093175], dtype=float32), 388: array([-1.1609757 , -1.6835822 , -1.9664385 , -1.4092625 , -1.6729269 ,
# ...
#        -2.6965017, -3.2225783], dtype=float32), 2582: array([-3.0648718, -1.3550729, -1.1073155,  4.7409215, -1.5563476,
#        -2.5034463, -1.4047   ], dtype=float32), 2583: array([ 1.0245512 , -3.683527  , -0.47274092, -1.7705454 ,  4.1562214 ,
#        -3.788878  , -1.6590548 ], dtype=float32), 2584: array([-3.2270381 ,  0.91956484,  2.1851504 ,  0.3370006 , -2.7546296 ,
#        -2.434556  , -2.4620802 ], dtype=float32), 2585: array([-3.7214427 , -0.13529757,  3.8401022 ,  0.8639251 , -1.3530555 ,
#        -3.4535344 , -3.4666438 ], dtype=float32), 2586: array([-3.1708784 , -0.76741755, -1.3845947 ,  0.3604535 , -1.452179  ,
#        -0.507199  , -0.02208009], dtype=float32), 2587: array([-0.8395128 , -1.0023645 , -0.48432824, -0.47296113,  3.811153  ,
#        -3.0671968 , -1.7249434 ], dtype=float32), 2588: array([-1.0970008 , -0.22827572, -1.1987288 ,  3.2845545 , -0.31381273,
#        -1.6150928 , -3.0166175 ], dtype=float32), 2589: array([-0.59345406, -0.8774097 , -0.05033603,  0.50129443,  0.14657623,
#        -1.2983261 , -1.0883403 ], dtype=float32), 2590: array([-2.7949083 , -0.81484705, -1.1825814 , -1.0899663 ,  0.19659372,
#        -0.3978501 , -0.4436118 ], dtype=float32), 2591: array([-1.0229809,  4.2886114, -1.268594 , -2.236991 , -3.721141 ,
#        -1.1461378, -2.186973 ], dtype=float32), 2592: array([-2.932791  ,  0.11088329, -3.136372  , -0.804428  , -2.6087677 ,
#         3.8956742 , -2.0996008 ], dtype=float32), 2593: array([-0.20994152, -1.4102412 , -1.8151131 ,  1.1739017 , -0.57085514,
#        -0.4959169 , -2.1108756 ], dtype=float32), 2594: array([-2.1435447 , -1.2531881 , -1.0410845 ,  0.92898357,  1.8879585 ,
#        -1.971195  , -1.191093  ], dtype=float32), 2595: array([-1.293056  ,  0.96775544, -1.3828137 ,  2.2481709 , -0.41302127,
#        -1.5649334 , -2.6072288 ], dtype=float32), 2596: array([-4.3086686, -1.0820792,  4.5603843, -1.9274154, -3.2045906,
#        -1.7369834, -2.5762794], dtype=float32), 2597: array([-3.7300587 , -0.68224037,  3.1444094 , -0.35805959, -2.0956247 ,
#        -2.6819851 , -2.7493918 ], dtype=float32), 2598: array([-0.878358 ,  2.1752038, -1.4383926, -1.614333 , -2.287758 ,
#        -1.1974915, -1.0743319], dtype=float32), 2599: array([-1.7402614 , -0.9892351 , -0.42790622,  3.0411339 , -0.5082535 ,
#        -1.5619597 , -2.7920172 ], dtype=float32), 2600: array([-0.37614208, -2.7361042 ,  0.17129056, -2.1924393 ,  0.5955816 ,
#        -1.1548696 , -1.9203707 ], dtype=float32), 2601: array([-0.6687906,  1.0329576, -0.0068309,  1.0057995, -3.5533664,
#        -2.4514978, -3.5636384], dtype=float32), 2602: array([-1.1930543 , -1.2917954 , -0.3796763 ,  0.17989355, -0.58672523,
#        -3.5106256 , -1.8697463 ], dtype=float32), 2603: array([-1.1930543 , -1.2917954 , -0.3796763 ,  0.17989355, -0.58672523,
#        -3.5106256 , -1.8697463 ], dtype=float32), 2604: array([-2.3601568, -3.8763108, -2.415985 , -2.9373913, -2.7362921,
#        -2.802164 ,  6.5514407], dtype=float32), 2605: array([-1.210547  , -0.22816345, -0.17397146,  4.1270356 , -0.80903405,
#        -2.3185897 , -3.7864559 ], dtype=float32), 2606: array([ 0.6833223, -1.9077477,  1.6467605, -2.7655048, -0.3194968,
#        -3.504649 , -1.2650465], dtype=float32), 2607: array([-3.0288594 , -1.5997434 ,  2.5664907 , -0.40972427,  0.55855936,
#        -2.2247858 , -1.9566399 ], dtype=float32), 2608: array([-3.4503772, -3.0704827, -2.9399364, -2.6771235, -3.2723868,
#        -2.2575738,  5.4961524], dtype=float32), 2609: array([-0.9662423 ,  1.1389158 , -0.30701375,  0.48051214, -3.4725177 ,
#        -2.1659536 , -3.4190848 ], dtype=float32), 2610: array([-1.8213105 , -0.5711008 , -0.76057434,  3.1140175 , -1.0713005 ,
#        -1.6623677 , -3.1039276 ], dtype=float32), 2611: array([ 1.1298456 , -3.338069  , -0.8947894 , -1.5354661 , -0.86734027,
#        -1.6463839 , -0.5566912 ], dtype=float32), 2612: array([-6.698772 ,  1.4115406,  5.336639 ,  2.4604726, -1.5592265,
#        -4.114845 , -5.0839067], dtype=float32), 2613: array([-1.5517809 , -0.37282473, -0.29776222,  3.851832  , -0.47423977,
#        -1.9505124 , -2.1532915 ], dtype=float32), 2614: array([-4.8023987, -3.1777036,  5.3483796, -2.2804198, -3.1956482,
#        -3.2381983, -1.4777021], dtype=float32), 2615: array([-1.3633049, -1.9091147, -1.3060756,  1.0518303,  2.339644 ,
#        -2.998654 , -0.7299472], dtype=float32), 2616: array([-3.7343478, -2.8729515,  4.313984 , -2.5297017, -1.9433553,
#        -1.1276029, -2.5160446], dtype=float32), 2617: array([-3.5671618 , -2.5859485 , -3.1393557 , -0.94659066,  0.58100164,
#         1.6611793 , -1.2048534 ], dtype=float32), 2618: array([-2.3669286, -2.699145 ,  0.9818973,  0.8642056, -0.769538 ,
#        -1.9771909, -1.5877748], dtype=float32), 2619: array([-2.3669286, -2.699145 ,  0.9818973,  0.8642056, -0.769538 ,
#        -1.9771909, -1.5877748], dtype=float32), 2620: array([ 2.5344305 ,  0.49756005, -2.077375  , -0.96462715, -1.3213456 ,
#        -1.7971133 , -2.295788  ], dtype=float32), 2621: array([-3.597071 , -2.3851607, -2.821651 , -2.6774516, -2.3527591,
#         6.6786466, -2.249194 ], dtype=float32), 2622: array([-1.8035166 , -2.1889508 , -1.7514124 , -0.25168186, -1.7195065 ,
#        -0.1527014 ,  1.0253339 ], dtype=float32), 2623: array([ 1.128417  , -3.3801389 , -1.7316203 , -1.1591115 ,  1.5332873 ,
#        -0.73670256, -0.7467151 ], dtype=float32), 2624: array([-4.0970626, -4.9201784, -1.4075053,  5.3843923, -1.8568757,
#        -1.3876193, -1.285464 ], dtype=float32), 2625: array([-4.333382  , -1.8844017 ,  0.5378844 ,  7.0513783 , -0.31589115,
#        -3.2443774 , -2.839047  ], dtype=float32), 2626: array([-4.333382  , -1.8844017 ,  0.5378844 ,  7.0513783 , -0.31589115,
#        -3.2443774 , -2.839047  ], dtype=float32), 2627: array([-2.9244726, -1.7356832,  4.320572 , -1.1461899, -2.0918381,
#        -1.5171921, -2.922967 ], dtype=float32), 2628: array([-3.2987754, -1.6637299, -1.7089491, -2.3836389, -3.4319217,
#         4.4168057, -1.6045378], dtype=float32), 2629: array([-1.0945796 , -1.0335101 ,  0.82575536,  5.799263  , -2.6074302 ,
#        -3.9362345 , -3.5701401 ], dtype=float32), 2630: array([-1.6549226 , -0.48063543, -1.8871593 ,  1.4406092 , -2.1187894 ,
#         0.23171191, -1.3606504 ], dtype=float32), 2631: array([-2.8079567 , -1.8211948 ,  0.01170319, -1.4739728 ,  5.3316364 ,
#        -2.1981707 , -2.1964002 ], dtype=float32), 2632: array([-3.2730196 , -1.6277906 , -0.09594946,  4.090115  , -1.18555   ,
#        -1.7147055 , -1.8501332 ], dtype=float32), 2633: array([-3.3296068 , -2.4720316 , -0.87869346, 10.056531  , -2.1935327 ,
#        -3.7138987 , -3.0250154 ], dtype=float32), 2634: array([-2.558636  ,  0.36438844, -0.97448725,  6.323158  , -1.3390474 ,
#        -2.5749457 , -3.926479  ], dtype=float32), 2635: array([-1.8263471,  0.1898323, -1.0332332,  4.429875 , -0.9828214,
#        -2.0321627, -2.7009404], dtype=float32), 2636: array([-2.8247752 ,  0.80682755, -0.41521782,  6.677299  , -1.6272955 ,
#        -2.6232526 , -4.6513133 ], dtype=float32), 2637: array([-2.1104004,  1.3393227, -1.0814543, -1.2543318,  2.7029715,
#        -2.2570052, -2.2773194], dtype=float32), 2638: array([-1.1921932, -2.7346482, -2.8286896, -3.3605013, -1.372366 ,
#        -1.0884686,  3.9849908], dtype=float32), 2639: array([-1.5149344 , -4.8586698 ,  0.88098115, -3.7293448 , -1.0449336 ,
#        -3.0895145 ,  2.4456983 ], dtype=float32), 2640: array([-0.88811266, -0.8943284 , -2.4444594 , -0.44755363, -1.0799351 ,
#         0.08891146, -1.1590831 ], dtype=float32), 2641: array([-3.6359293 , -2.2871656 ,  2.5634875 , -3.2755995 , -3.4993036 ,
#        -1.324582  ,  0.78594375], dtype=float32), 2642: array([-1.9816136, -2.1347885,  5.388423 , -2.6207213, -2.4872358,
#        -3.5051868, -2.9987082], dtype=float32), 2643: array([-3.1413743 , -2.0179949 ,  4.821128  , -0.05993962, -2.2813146 ,
#        -2.4709728 , -3.1940758 ], dtype=float32), 2644: array([ 0.18377227, -2.784408  , -1.001615  , -1.5312233 , -1.4135954 ,
#        -0.33312947, -0.43438977], dtype=float32), 2645: array([-1.4545122, -1.9262421, -0.7360175, -1.4185178,  4.5201235,
#        -1.8283311, -1.4032947], dtype=float32), 2646: array([-2.4466026 , -0.9065911 , -1.0785074 , -0.38962516,  4.871434  ,
#        -2.098891  , -1.8069175 ], dtype=float32), 2647: array([-0.5081087 , -2.8665862 , -2.1642175 ,  0.11610609,  4.37789   ,
#        -3.2437375 , -1.8158485 ], dtype=float32), 2648: array([-0.30864412, -2.6561537 , -2.2256525 , -1.2014638 ,  6.496237  ,
#        -3.2938488 , -1.7422156 ], dtype=float32), 2649: array([-2.97286   , -1.6014429 , -2.9888518 , -4.486654  , -3.2981071 ,
#         0.83261997,  2.0610225 ], dtype=float32), 2650: array([-2.524153 ,  0.7724198, -0.5257356,  3.7999196, -1.742614 ,
#        -2.6475625, -2.6485453], dtype=float32), 2651: array([-1.8893635, -2.3675025,  4.759713 , -4.2075696, -2.8205159,
#        -2.9968853, -1.809612 ], dtype=float32), 2652: array([-3.4216392 , -0.84677756,  3.6804981 , -1.8097501 , -2.32871   ,
#        -1.858211  , -1.8355594 ], dtype=float32), 2653: array([-1.9853578 , -1.2633868 , -1.2425854 , -0.7669078 , -1.2931759 ,
#        -1.8252902 , -0.02782002], dtype=float32), 2654: array([-0.20897536, -2.560246  ,  1.8268661 , -1.2328943 , -1.7553189 ,
#        -2.6674027 , -1.1695013 ], dtype=float32), 2655: array([ 0.8104325 , -1.1956526 ,  0.03056002,  0.01226315, -0.99539167,
#        -1.9789109 , -0.94568086], dtype=float32), 2656: array([-0.9190483, -0.9305936,  0.6930697, -3.0111747, -3.3140047,
#        -1.8612747, -0.5192973], dtype=float32), 2657: array([-2.5715497 , -0.95105946,  4.5584784 , -0.93216157, -1.2974734 ,
#        -2.5699275 , -3.5059783 ], dtype=float32), 2658: array([-3.3012002, -1.5261273,  5.4654493, -0.4820425, -1.3213043,
#        -3.0949795, -4.8281198], dtype=float32), 2659: array([-1.5292351 , -0.21717216, -0.40053657,  2.481227  ,  0.21439405,
#        -2.9941032 , -2.0027676 ], dtype=float32), 2660: array([ 0.72515774, -1.9013278 , -1.1879804 , -0.1469195 ,  1.1278851 ,
#        -0.44683695, -1.3883275 ], dtype=float32), 2661: array([-1.6032481 , -0.9314812 , -1.0943274 , -0.8073727 ,  4.2029486 ,
#        -0.9464471 , -0.98594046], dtype=float32), 2662: array([-1.607427  , -1.0938902 , -1.1548848 , -0.72117984,  4.5930696 ,
#        -1.2820966 , -1.0680273 ], dtype=float32), 2663: array([-0.00696655, -0.68422127, -0.7331006 ,  3.4197125 , -1.407007  ,
#        -2.8529334 , -3.5668929 ], dtype=float32), 2664: array([ 1.0401572,  0.7527499, -2.1088486,  1.7066904, -1.666091 ,
#        -1.243755 , -1.3688354], dtype=float32), 2665: array([-1.266297  , -0.7711707 , -1.0710266 ,  0.78123   ,  0.22875853,
#        -1.26173   , -0.83312786], dtype=float32), 2666: array([-1.266297  , -0.7711707 , -1.0710266 ,  0.78123   ,  0.22875853,
#        -1.26173   , -0.83312786], dtype=float32), 2667: array([-1.7127658, -1.3923986, -2.3798018,  6.5908866, -1.6147959,
#        -3.262858 , -2.6365926], dtype=float32), 2668: array([-1.4797782, -1.4924303, -2.3783336,  6.0420747, -1.1895237,
#        -3.049701 , -2.5268247], dtype=float32), 2669: array([ 1.5042781 , -2.4320686 , -0.35271272,  0.9887588 , -0.5345572 ,
#        -3.009146  , -0.5286716 ], dtype=float32), 2670: array([-2.5505197, -1.6432362, -1.0352972, -2.456409 ,  3.994062 ,
#        -2.192235 , -0.682034 ], dtype=float32), 2671: array([-1.7204514, -2.7893105,  0.143282 , -4.119468 ,  5.0804653,
#        -4.5048294, -3.2708354], dtype=float32), 2672: array([-0.7180566 , -1.2325941 ,  0.03881932, -1.4936285 ,  2.719035  ,
#        -2.1727448 , -1.3648992 ], dtype=float32), 2673: array([-0.49511468, -1.3847458 , -0.22746396, -1.7317442 ,  2.6978147 ,
#        -2.3171463 , -1.4392982 ], dtype=float32), 2674: array([ 0.20596829, -1.716313  , -0.06203745, -2.748139  ,  2.8992422 ,
#        -2.8554792 , -2.0566313 ], dtype=float32), 2675: array([ 0.20596829, -1.7163131 , -0.06203745, -2.748139  ,  2.8992422 ,
#        -2.8554792 , -2.0566313 ], dtype=float32), 2676: array([-2.359447 ,  0.6190991, -2.1527407,  2.320603 ,  0.1799837,
#        -1.3561275, -2.2495153], dtype=float32), 2677: array([-1.1828746 , -1.5562606 , -0.73797166,  0.13970912,  2.8116093 ,
#        -2.9499497 , -1.0061789 ], dtype=float32), 2678: array([-1.0105768, -1.4841466, -0.5252464, -1.5594774,  2.4421303,
#        -1.9280995, -1.1858803], dtype=float32), 2679: array([-1.2360492 , -1.6372805 , -0.44503137, -3.5579262 ,  3.278601  ,
#        -2.9633331 , -1.4672551 ], dtype=float32), 2680: array([-2.29577   , -1.4417105 , -0.6539958 , -0.42294818,  3.3168828 ,
#        -2.4683151 , -0.994859  ], dtype=float32), 2681: array([-0.9964342, -2.44882  ,  1.9479272, -3.679123 ,  1.8023787,
#        -5.877362 , -1.9644347], dtype=float32), 2682: array([-0.38806367, -1.2868733 , -0.4020379 , -3.2007675 ,  2.6280134 ,
#        -2.2389457 , -1.0053495 ], dtype=float32), 2683: array([-0.02704348, -1.8012159 ,  1.047565  , -1.6543849 ,  1.0079546 ,
#        -3.460095  , -1.2281722 ], dtype=float32), 2684: array([-2.4105465 , -1.7380183 , -1.1060638 ,  0.59298575,  3.2792366 ,
#        -1.8638388 , -0.61599815], dtype=float32), 2685: array([-2.467838 , -2.159934 ,  4.677132 , -2.422102 , -2.5440204,
#        -2.4788733, -2.4576695], dtype=float32), 2686: array([-1.1239827 , -0.21142241, -0.7341274 ,  2.3609343 , -0.37187457,
#        -0.6892303 , -1.7785625 ], dtype=float32), 2687: array([-0.8095124,  0.5183201, -1.2717838,  3.062849 , -0.2946664,
#        -1.5463235, -2.3256395], dtype=float32), 2688: array([-1.1135591 ,  0.38708946, -1.2778144 ,  3.3752704 , -0.4807045 ,
#        -1.4161172 , -2.5039089 ], dtype=float32), 2689: array([-2.4882808, -0.7603313,  1.1621635,  1.2284278, -0.570322 ,
#        -2.4160051, -1.5350664], dtype=float32), 2690: array([-0.6121271 , -1.4078609 , -2.4876738 ,  1.3506491 , -0.8997956 ,
#        -0.39474005, -1.2244982 ], dtype=float32), 2691: array([-5.186275 , -1.4082875,  6.2791543, -1.8833265, -2.3150551,
#        -4.918568 , -3.1927545], dtype=float32), 2692: array([-4.5312066, -2.4174385, -1.973242 , -2.0522223, -3.6183355,
#         0.9718544,  2.435714 ], dtype=float32), 2693: array([-2.4394095 ,  0.71135306, -0.13497782,  6.0324078 , -1.3182583 ,
#        -2.3650775 , -4.370953  ], dtype=float32), 2694: array([-0.10368173, -2.7944517 , -2.1496665 , -2.2778938 ,  7.1319847 ,
#        -4.1887765 , -0.68482035], dtype=float32), 2695: array([-0.1036817 , -2.7944517 , -2.1496665 , -2.2778938 ,  7.1319847 ,
#        -4.1887765 , -0.68482035], dtype=float32), 2696: array([-1.4935168, -1.764952 , -0.825025 ,  1.3263334,  1.4247782,
#        -2.480773 , -0.6207376], dtype=float32), 2697: array([-4.3066282e+00, -1.2956891e+00,  4.1573569e-03,  8.1601906e+00,
#        -6.5939552e-01, -4.4035168e+00, -5.1048427e+00], dtype=float32), 2698: array([-4.7391343 , -1.4040196 , -0.07859991,  7.7274165 , -3.0658996 ,
#        -2.5498633 , -2.6842587 ], dtype=float32), 2699: array([-1.5642607 , -0.18944567, -1.7779484 ,  1.4083762 , -1.8487256 ,
#         0.0937268 , -1.2302239 ], dtype=float32), 2700: array([-2.2499206 , -1.7563218 , -0.42456853,  1.4023844 , -3.2360904 ,
#        -0.14108485, -0.76617455], dtype=float32), 2701: array([-4.0970626, -4.9201784, -1.4075053,  5.384392 , -1.8568757,
#        -1.3876193, -1.285464 ], dtype=float32), 2702: array([ 1.3967503 , -1.197109  , -1.7320371 ,  1.2052166 ,  0.13103333,
#        -2.4740486 , -1.5682371 ], dtype=float32), 2703: array([-0.82276213, -1.721595  , -1.4825072 ,  6.465669  , -1.6406384 ,
#        -2.7914023 , -2.9631004 ], dtype=float32), 2704: array([-0.95319414, -2.7533576 ,  1.4751418 , -0.43944383,  0.65496147,
#        -1.5852848 , -1.6929803 ], dtype=float32), 2705: array([ 1.1461047 ,  0.9642745 , -4.2250466 , -0.93054706, -3.660786  ,
#         0.98021275, -1.0480478 ], dtype=float32), 2706: array([-2.2886665 , -0.20450953, -1.0295486 ,  5.2785974 , -0.3718235 ,
#        -2.6930137 , -3.742228  ], dtype=float32), 2707: array([-2.0385938 , -0.07726617, -0.9160692 ,  4.835208  , -0.64674646,
#        -2.3165734 , -3.5739655 ], dtype=float32)}

# %% [markdown]
# #Community Detection

# %%
# !pip uninstall -y python-louvain
# !pip install python-louvain
# Out:
# Found existing installation: python-louvain 0.16
# Uninstalling python-louvain-0.16:
#   Successfully uninstalled python-louvain-0.16
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from python-louvain) (3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-louvain) (1.25.2)
# Building wheels for collected packages: python-louvain
#   Building wheel for python-louvain (setup.py) ... done
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9389 sha256=3bc75a4f6fd618e52693553bf30939f2eef6149380e6bf52c1e8681707200a9a
#   Stored in directory: /root/.cache/pip/wheels/d0/b0/d7/6dd26c3817810fa379088eaeb755a01d9a2a411c37632079d1
# Successfully built python-louvain
# Installing collected packages: python-louvain
# Successfully installed python-louvain-0.16

# %%
from community import community_louvain

# %%
# Louvain community detection with enhanced features
partition = community_louvain.best_partition(G, weight='embedding')  # Use 'embedding' attribute
# Extract community labels
community_labels = list(partition.values())

isolated_nodes = []
small_components = []

for node, community_id in partition.items():
    if len([n for n, cid in partition.items() if cid == community_id]) == 1:
        isolated_nodes.append(node)
    elif len([n for n, cid in partition.items() if cid == community_id]) <= 5:
        small_components.append(node)

print("Isolated Nodes:", isolated_nodes)
print("Small Connected Components:", small_components)

for nodes, community_id in partition.items():
  G.nodes[node]['community'] = community_id
  print(f"Community of {nodes}: {community_id}")
# Out:
# Isolated Nodes: []
# Small Connected Components: [2544, 3, 208, 7, 1001, 12, 1318, 2661, 2662, 1594, 31, 1582, 44, 2624, 2701, 2631, 66, 2461, 106, 259, 117, 2537, 520, 184, 1208, 187, 1439, 200, 2676, 821, 222, 2255, 225, 2583, 247, 2429, 250, 2705, 287, 2562, 292, 991, 307, 385, 369, 2484, 477, 380, 930, 2569, 2483, 1108, 390, 1170, 404, 1476, 545, 422, 2694, 431, 2695, 1048, 462, 1181, 474, 1286, 538, 774, 560, 2526, 585, 1032, 587, 2669, 592, 2690, 611, 1024, 625, 2058, 635, 2704, 641, 1231, 653, 932, 662, 954, 677, 2629, 692, 1691, 700, 1044, 713, 1034, 721, 2341, 780, 947, 786, 2600, 832, 2639, 917, 2173, 939, 2565, 953, 2566, 2567, 1112, 2529, 959, 2659, 967, 1496, 974, 2697, 986, 1541, 1005, 1036, 1600, 1059, 1648, 1210, 2433, 1233, 2479, 1236, 1407, 1263, 2703, 1298, 2692, 1310, 1613, 1356, 1393, 1371, 2586, 1375, 1544, 1378, 2150, 2664, 1438, 1657, 1554, 2686, 2687, 2688, 2633, 1563, 2660, 1673, 2174, 2411, 2410, 2432, 2431, 2603, 2602, 2619, 2618, 2626, 2625, 2635, 2634, 2636, 2693, 2666, 2665]
# Community of 1673: 102
# Community of 1680: 6
# Community of 2576: 6
# Community of 2318: 23
# Community of 2320: 23
# Community of 2321: 23
# Community of 1684: 44
# Community of 2513: 44
# Community of 1686: 49
# Community of 2345: 39
# Community of 1696: 31
# Community of 2253: 25
# Community of 1820: 0
# Community of 1852: 0
# Community of 1853: 0
# Community of 1854: 0
# Community of 1859: 0
# Community of 1860: 0
# Community of 1861: 0
# Community of 1867: 0
# Community of 1872: 0
# Community of 1876: 0
# Community of 1877: 77
# Community of 1971: 18
# Community of 1969: 18
# Community of 2322: 10
# Community of 2413: 9
# Community of 2257: 14
# Community of 2389: 5
# Community of 2593: 20
# Community of 1796: 18
# Community of 2299: 18
# Community of 2297: 18
# Community of 1811: 2
# Community of 1822: 2
# Community of 2550: 2
# Community of 2573: 77
# Community of 2644: 20
# Community of 1890: 2
# Community of 1891: 2
# Community of 2039: 2
# Community of 1897: 31
# Community of 2510: 31
# Community of 2284: 31
# Community of 2404: 20
# Community of 1915: 17
# Community of 2649: 17
# Community of 2620: 6
# Community of 2475: 7
# Community of 1938: 14
# Community of 2204: 2
# Community of 2630: 31
# Community of 2621: 31
# Community of 1990: 0
# Community of 1991: 6
# Community of 2002: 1
# Community of 2005: 0
# Community of 2007: 0
# Community of 2477: 9
# Community of 2467: 20
# Community of 2028: 7
# Community of 2042: 2
# Community of 2311: 6
# Community of 2098: 0
# Community of 2588: 0
# Community of 2637: 1
# Community of 2142: 0
# Community of 2331: 14
# Community of 2158: 19
# Community of 2171: 7
# Community of 2174: 82
# Community of 2231: 23
# Community of 2193: 7
# Community of 2511: 6
# Community of 2521: 2
# Community of 2292: 23
# Community of 2239: 18
# Community of 2242: 9
# Community of 2245: 9
# Community of 2337: 1
# Community of 2496: 18
# Community of 2298: 18
# Community of 2552: 23
# Community of 2559: 2
# Community of 2328: 10
# Community of 2368: 13
# Community of 2369: 13
# Community of 2370: 13
# Community of 2397: 20
# Community of 2411: 103
# Community of 2410: 103
# Community of 2417: 7
# Community of 2426: 11
# Community of 2428: 20
# Community of 2432: 32
# Community of 2431: 32
# Community of 2452: 5
# Community of 2689: 28
# Community of 2468: 20
# Community of 2540: 9
# Community of 2632: 9
# Community of 2561: 5
# Community of 2572: 77
# Community of 2603: 34
# Community of 2602: 34
# Community of 2696: 1
# Community of 2619: 16
# Community of 2618: 16
# Community of 2626: 24
# Community of 2625: 24
# Community of 2699: 31
# Community of 2635: 26
# Community of 2634: 26
# Community of 2636: 26
# Community of 2693: 26
# Community of 2655: 5
# Community of 2666: 29
# Community of 2665: 29
# Community of 2672: 49
# Community of 2683: 49

# %%
# Assuming 'community_labels' contains the community labels
unique_labels = set(community_labels)
total_community_labels = len(unique_labels)

print(f"Total number of community labels: {total_community_labels}")
# Out:
# Total number of community labels: 104

# %%
def get_community_label(node_id):
  for nodes, community_id in partition.items():
    if(nodes==node_id):
      return community_id
    else:
      continue

def get_community_info(node_id):
    community_label=get_community_label(node_id)
    # Get the nodes in the same community as the input node
    community_nodes = [node for node, cid in partition.items() if cid == community_label]

    # Compute degree centrality for the input node within its community
    community_subgraph = G.subgraph(community_nodes)
    node_degree_centrality = nx.degree_centrality(community_subgraph)
    influence = node_degree_centrality[node_id]

    print(f"Node {node_id} has degree centrality of {influence:.3f} in Community {community_label}.")
    return community_nodes

# %%
# Visualize all nodes and their communities
pos = nx.spring_layout(G, seed=42)
plt.figure(figsize=(10,8))
plt.title("Cora Community Detection (Louvain)")
nx.draw_networkx_nodes(G, pos, node_size=10, node_color=community_labels, cmap=plt.cm.get_cmap('viridis', max(community_labels) + 1))
nx.draw_networkx_edges(G, pos, alpha=1)
plt.axis('off')

plt.show()
# Out:
# <ipython-input-22-d3e6d452745b>:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   nx.draw_networkx_nodes(G, pos, node_size=10, node_color=community_labels, cmap=plt.cm.get_cmap('viridis', max(community_labels) + 1))

# %% [markdown]
# Visualization

# %%
print("Number of nodes:", len(G.nodes))
print("Number of communities:", len(set(community_labels)))
# Out:
# Number of nodes: 2708
# Number of communities: 104

# %% [markdown]
# # Display Paper Details Under Various Categories After Classification

# %%
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.2.1)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Installing collected packages: jedi
# Successfully installed jedi-0.19.1

# %%
import re
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML  # Import HTML for creating clickable links

class_labels_to_names = {
    0: 'Theory',
    1: 'Reinforcement_Learning',
    2: 'Genetic_Algorithms',
    3: 'Neural_Networks',
    4: 'Probabilistic_Methods',
    5: 'Case_Based',
    6: 'Rule_Learning'
}

# Assuming you have defined 'model', 'data', 'aligned_titles', and 'class_labels_to_names' before this point

# Set the model to evaluation mode
model.eval()

# Forward pass to get predictions
out = model(data.x, data.edge_index)

# Get predicted labels
predicted_labels = out.argmax(dim=1)

# Replace class labels with category names
predicted_category_names = [class_labels_to_names[label.item()] for label in predicted_labels]

# Create a dictionary to store lists of titles for each category
category_titles = {category_name: [] for category_name in class_labels_to_names.values()}
category_titles['Miscellaneous'] = []

# Loop through predicted category names and aligned titles
for idx, category_name in enumerate(predicted_category_names):
    # Find the original index in the dataframe based on PyG's node indices
    mask_indices = (data.test_mask.nonzero().view(-1) == idx).nonzero()

    # Check if the index is found and within the bounds of the aligned_titles list
    if mask_indices.numel() > 0:
        original_idx = mask_indices.item()
        if original_idx < len(aligned_titles):
            # Remove text enclosed in square brackets from the title
            cleaned_title = re.sub(r'\[.*?\]', '', aligned_titles[original_idx]).strip()

            # Append the cleaned title to the corresponding category's list
            category_titles[category_name].append(cleaned_title)

#print(category_titles)

# %%
# Dictionary to store modified titles
modified_category = {}

# Loop through each category and its titles
for category, titles in category_titles.items():
    modified_category[category] = []  # Initialize an empty list for each category
    for title in titles:
        # Extract text within '<>' using regular expression
        key_value_pairs = re.findall(r'<(.*?)>(.*?)</\1>', title)
        row_data = {}  # Initialize a dictionary to store row data
        for key, value in key_value_pairs:
            # Add key-value pairs to the row_data dictionary
            row_data[key] = value
        # Append the row_data to the modified_category list for the current category
        modified_category[category].append(row_data)

# Print the modified titles dictionary
#print(modified_category)

# %%
import pandas as pd

all_papers_df = []  # Changed to list
title_df = []  # Changed to list

# Loop through each category and its list of dictionaries
for category, rows_list in modified_category.items():
    for row_data in rows_list:
        # Extract data from each row
        author = row_data.get('author', 'Unknown')
        title = row_data.get('title', 'Unknown')
        year = row_data.get('year', 'Unknown')
        publisher = row_data.get('publisher', 'Unknown')
        journal = row_data.get('journal', 'Unknown')
        booktitle = row_data.get('booktitle', 'Unknown')

        # Remove double quotation symbols from the title
        title = title.replace('"', '')

        # Append a row of data to the all_papers_df list
        all_papers_df.append({'Category': category, 'Author': author, 'Title': title, 'Year': year, 'Publisher': publisher, 'Journal': journal, 'Booktitle': booktitle})

        # Append a row to the title_df list (if needed)
        title_df.append({'Category': category, 'Title': title})

# Create DataFrames from the lists
all_papers_df = pd.DataFrame(all_papers_df)
title_df = pd.DataFrame(title_df)

# Drop duplicate rows from all_papers_df to display only unique rows
all_papers_df.drop_duplicates(inplace=True)
title_df.drop_duplicates(inplace=True)

# Add 'node_id' as a new column with index values to all_papers_df DataFrame
all_papers_df['NodeID'] = all_papers_df.index

# Assuming 'node_id' column exists in all_papers_df
all_papers_df["CommunityID"] = all_papers_df["NodeID"].apply(get_community_label)

# Display the DataFrames
print("All Papers DataFrame:")
print(all_papers_df)
print("\nTitle DataFrame:")
print(title_df)
# Out:
# All Papers DataFrame:
#           Category                                             Author  \
# 0           Theory                      Liskov B., Day M., Shrira L.
# 1           Theory   Dawson R. Engler, M. Frans Kaashoek, and Jame...
# 2           Theory   Christos Faloutsos, M. Ranganathan, and Yanni...
# 5           Theory   F. Korn, N. Sidiropolous, C. Faloutos, E. Sie...
# 7           Theory   R.G. Covington, S. Dwarkadas, J.R. Jump, J.B....
# ..             ...                                                ...
# 995  Rule_Learning           R. Canetti, O. Goldreich and S. Halevi.
# 996  Rule_Learning            R. Canetti, S. Halevi and A. Herzberg,
# 997  Rule_Learning                                     O. Goldreich.
# 998  Rule_Learning                        O. Goldreich and A. Kahan.
# 999  Rule_Learning                       R. Greiner and I. Jurisica,
#
#                                                  Title     Year Publisher  \
# 0              Distributed Object Management in Thor.    1993.    Unknown
# 1     An operating system architecture for applicat...  Unknown   Unknown
# 2     Fast subsequence matching in time-series data...   1994.    Unknown
# 5     Fast nearest neighbor search in medical image...   1996.    Unknown
# 7     The Efficient Simulation of Parallel Computer...   1991.    Unknown
# ..                                                 ...      ...       ...
# 995               The random oracle model, revisited.    1998.    Unknown
# 996      How to Maintain Authenticated Communication,    1997.    Unknown
# 997   Lecture Notes on Encryption, Signatures and C...  Unknown   Unknown
# 998   How to Construct Constant-Round Zero-Knowledg...   1996,    Unknown
# 999   A Statistical Approach to Solving the EBL Uti...   1992,    Unknown
#
#                                              Journal  \
# 0                                            Unknown
# 1                                            Unknown
# 2                                            Unknown
# 5                                            Unknown
# 7     International Journal in Computer Simulation,
# ..                                               ...
# 995                                          Unknown
# 996                                          Unknown
# 997                                          Unknown
# 998                          Journal of Cryptology,
# 999                                          Unknown
#
#                                              Booktitle  NodeID  CommunityID
# 0                      Distributed Object Management.        0            0
# 1     In Proceedings of the Fifteenth ACM Symposium...       1           22
# 2                                   Proc. ACM SIGMOD,        2           22
# 5     International Conference on Very Large Data B...       5            6
# 7                                              Unknown       7            9
# ..                                                 ...     ...          ...
# 995   Proceedings of the 30th Annual Symposium on t...     995           23
# 996                                        16th PODC,      996           49
# 997                                            Unknown     997           39
# 998                                            Unknown     998            6
# 999   Proceedings of the Na tional Conference on Ar...     999            6
#
# [674 rows x 9 columns]
#
# Title DataFrame:
#           Category                                              Title
# 0           Theory            Distributed Object Management in Thor.
# 1           Theory   An operating system architecture for applicat...
# 2           Theory   Fast subsequence matching in time-series data...
# 5           Theory   Fast nearest neighbor search in medical image...
# 7           Theory   The Efficient Simulation of Parallel Computer...
# ..             ...                                                ...
# 995  Rule_Learning               The random oracle model, revisited.
# 996  Rule_Learning      How to Maintain Authenticated Communication,
# 997  Rule_Learning   Lecture Notes on Encryption, Signatures and C...
# 998  Rule_Learning   How to Construct Constant-Round Zero-Knowledg...
# 999  Rule_Learning   A Statistical Approach to Solving the EBL Uti...
#
# [674 rows x 2 columns]

# %%
import pandas as pd
all_papers_df = pd.read_csv('updated.csv')

# %%
print(all_papers_df)
# Out:
#           Category                                             Author  \
# 0           Theory                      Liskov B., Day M., Shrira L.
# 1           Theory   Dawson R. Engler, M. Frans Kaashoek, and Jame...
# 2           Theory   Christos Faloutsos, M. Ranganathan, and Yanni...
# 3           Theory   F. Korn, N. Sidiropolous, C. Faloutos, E. Sie...
# 4           Theory   R.G. Covington, S. Dwarkadas, J.R. Jump, J.B....
# ..             ...                                                ...
# 673  Rule_Learning           R. Canetti, O. Goldreich and S. Halevi.
# 674  Rule_Learning            R. Canetti, S. Halevi and A. Herzberg,
# 675  Rule_Learning                                     O. Goldreich.
# 676  Rule_Learning                        O. Goldreich and A. Kahan.
# 677  Rule_Learning                       R. Greiner and I. Jurisica,
#
#                                                  Title     Year Publisher  \
# 0              Distributed Object Management in Thor.      1993   Unknown
# 1     An operating system architecture for applicat...  Unknown   Unknown
# 2     Fast subsequence matching in time-series data...     1994   Unknown
# 3     Fast nearest neighbor search in medical image...     1996   Unknown
# 4     The Efficient Simulation of Parallel Computer...     1991   Unknown
# ..                                                 ...      ...       ...
# 673               The random oracle model, revisited.      1998   Unknown
# 674      How to Maintain Authenticated Communication,      1997   Unknown
# 675   Lecture Notes on Encryption, Signatures and C...  Unknown   Unknown
# 676   How to Construct Constant-Round Zero-Knowledg...   1996,    Unknown
# 677   A Statistical Approach to Solving the EBL Uti...   1992,    Unknown
#
#                                              Journal  \
# 0                                            Unknown
# 1                                            Unknown
# 2                                            Unknown
# 3                                            Unknown
# 4     International Journal in Computer Simulation,
# ..                                               ...
# 673                                          Unknown
# 674                                          Unknown
# 675                                          Unknown
# 676                          Journal of Cryptology,
# 677                                          Unknown
#
#                                              Booktitle  node_id  \
# 0                      Distributed Object Management.         0
# 1     In Proceedings of the Fifteenth ACM Symposium...        1
# 2                                   Proc. ACM SIGMOD,         2
# 3     International Conference on Very Large Data B...        5
# 4                                              Unknown        7
# ..                                                 ...      ...
# 673   Proceedings of the 30th Annual Symposium on t...      995
# 674                                        16th PODC,       996
# 675                                            Unknown      997
# 676                                            Unknown      998
# 677   Proceedings of the Na tional Conference on Ar...      999
#
#                                               Goto PDF
# 0       https://pmg.csail.mit.edu/papers/dist-mgmt.pdf
# 1    https://pdos.csail.mit.edu/6.828/2008/readings...
# 2    https://citeseerx.ist.psu.edu/document?repid=r...
# 3    https://citeseerx.ist.psu.edu/document?repid=r...
# 4    https://citeseerx.ist.psu.edu/document?repid=r...
# ..                                                 ...
# 673               https://eprint.iacr.org/1998/011.pdf
# 674  https://link.springer.com/content/pdf/10.1007/...
# 675  https://www.win.tue.nl/~berry/CryptographicPro...
# 676  https://www.wisdom.weizmann.ac.il/~oded/PSX/zk...
# 677      https://cdn.aaai.org/AAAI/1992/AAAI92-038.pdf
#
# [678 rows x 9 columns]

# %%
# Assuming 'node_id' column exists in all_papers_df
all_papers_df["CommunityID"] = all_papers_df["node_id"].apply(get_community_label)

# %%
print(all_papers_df)
# Out:
#           Category                                             Author  \
# 0           Theory                      Liskov B., Day M., Shrira L.
# 1           Theory   Dawson R. Engler, M. Frans Kaashoek, and Jame...
# 2           Theory   Christos Faloutsos, M. Ranganathan, and Yanni...
# 3           Theory   F. Korn, N. Sidiropolous, C. Faloutos, E. Sie...
# 4           Theory   R.G. Covington, S. Dwarkadas, J.R. Jump, J.B....
# ..             ...                                                ...
# 673  Rule_Learning           R. Canetti, O. Goldreich and S. Halevi.
# 674  Rule_Learning            R. Canetti, S. Halevi and A. Herzberg,
# 675  Rule_Learning                                     O. Goldreich.
# 676  Rule_Learning                        O. Goldreich and A. Kahan.
# 677  Rule_Learning                       R. Greiner and I. Jurisica,
#
#                                                  Title     Year Publisher  \
# 0              Distributed Object Management in Thor.      1993   Unknown
# 1     An operating system architecture for applicat...  Unknown   Unknown
# 2     Fast subsequence matching in time-series data...     1994   Unknown
# 3     Fast nearest neighbor search in medical image...     1996   Unknown
# 4     The Efficient Simulation of Parallel Computer...     1991   Unknown
# ..                                                 ...      ...       ...
# 673               The random oracle model, revisited.      1998   Unknown
# 674      How to Maintain Authenticated Communication,      1997   Unknown
# 675   Lecture Notes on Encryption, Signatures and C...  Unknown   Unknown
# 676   How to Construct Constant-Round Zero-Knowledg...   1996,    Unknown
# 677   A Statistical Approach to Solving the EBL Uti...   1992,    Unknown
#
#                                              Journal  \
# 0                                            Unknown
# 1                                            Unknown
# 2                                            Unknown
# 3                                            Unknown
# 4     International Journal in Computer Simulation,
# ..                                               ...
# 673                                          Unknown
# 674                                          Unknown
# 675                                          Unknown
# 676                          Journal of Cryptology,
# 677                                          Unknown
#
#                                              Booktitle  node_id  \
# 0                      Distributed Object Management.         0
# 1     In Proceedings of the Fifteenth ACM Symposium...        1
# 2                                   Proc. ACM SIGMOD,         2
# 3     International Conference on Very Large Data B...        5
# 4                                              Unknown        7
# ..                                                 ...      ...
# 673   Proceedings of the 30th Annual Symposium on t...      995
# 674                                        16th PODC,       996
# 675                                            Unknown      997
# 676                                            Unknown      998
# 677   Proceedings of the Na tional Conference on Ar...      999
#
#                                               Goto PDF  CommunityID
# 0       https://pmg.csail.mit.edu/papers/dist-mgmt.pdf            0
# 1    https://pdos.csail.mit.edu/6.828/2008/readings...           22
# 2    https://citeseerx.ist.psu.edu/document?repid=r...           22
# 3    https://citeseerx.ist.psu.edu/document?repid=r...            6
# 4    https://citeseerx.ist.psu.edu/document?repid=r...            9
# ..                                                 ...          ...
# 673               https://eprint.iacr.org/1998/011.pdf           23
# 674  https://link.springer.com/content/pdf/10.1007/...           49
# 675  https://www.win.tue.nl/~berry/CryptographicPro...           39
# 676  https://www.wisdom.weizmann.ac.il/~oded/PSX/zk...            6
# 677      https://cdn.aaai.org/AAAI/1992/AAAI92-038.pdf            6
#
# [678 rows x 10 columns]

# %%
all_papers_df.to_csv('_updated_.csv', index=False)

# %% [markdown]
# #Crossref search API - Habanero

# %%
# !pip install habanero
# Out:
# Collecting habanero
#   Downloading habanero-1.2.6-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from habanero) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from habanero) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->habanero) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->habanero) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->habanero) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.7.0->habanero) (2024.2.2)
# Installing collected packages: habanero
# Successfully installed habanero-1.2.6

# %%
from habanero import Crossref
import re

def find_doi_by_title_and_authors(title_to_find, author_names):
    cr = Crossref()

    # Split the author names by commas and "and"
    authors_list = [author.strip() for author in re.split(r',|and', author_names)]

    # Construct the query with title and authors
    query = f"title:{title_to_find}"
    if authors_list:
        query += " author:" + " author:".join(authors_list)

    results = cr.works(query=query)

    if results['message']['total-results'] > 0:
        item = results['message']['items'][0]
        doi = item.get('DOI', 'DOI not found')
        return doi
    else:
        return 'DOI not found'

# %% [markdown]
# # Search box and Display Papers Based on the Search Keyword

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML

# Assume 'all_papers_df' and 'title_df' DataFrames are populated
# Assume 'get_community_info' function is defined to fetch community information
# Assume 'community_labels' is a list containing community IDs

# Create a search box for entering keywords
keyword_search = widgets.Text(placeholder='Enter keyword.', description='Keyword:')

# Create a dropdown widget to display search results
dropdown_results = widgets.Dropdown(description='Search Results:', options=['Select'])

# Create an output widget to display the details of the selected title
details_output = widgets.Output()

# Create an output widget to display the table of papers with the same community ID
community_table_output = widgets.Output()

# Create an output widget to display the count of papers with node IDs not available in the dataframe
count_output = widgets.Output()

# Display the widgets
display(widgets.VBox([keyword_search, dropdown_results, details_output, community_table_output, count_output]))

# Function to update the dropdown options based on keyword search
def update_dropdown(change):
    keyword = keyword_search.value.lower().strip()
    if keyword:
        dropdown_results.options = ['Select'] + all_papers_df[
            all_papers_df.apply(lambda row: any(keyword in str(row[col]).lower() for col in all_papers_df.columns), axis=1)
        ]['Title'].tolist()
    else:
        dropdown_results.options = ['Select']

# Connect the search box to the update_dropdown function
keyword_search.observe(update_dropdown, names='value')

# Function to display details of the selected title
def display_details(selected_title):
    details_output.clear_output(wait=True)
    community_table_output.clear_output(wait=True)
    count_output.clear_output(wait=True)

    if selected_title != 'Select':
        selected_rows = all_papers_df[all_papers_df['Title'] == selected_title]
        if not selected_rows.empty:
            with details_output:
                for index, row in selected_rows.iterrows():
                    node_id = index
                    category = row['Category']
                    title = row['Title']
                    author = row['Author']
                    journal = row['Journal']
                    booktitle = row['Booktitle']

                    if node_id < len(community_labels):
                        community_id = community_labels[node_id]
                    else:
                        community_id = 'N/A'

                    doi = find_doi_by_title_and_authors(title,author)
                    if doi == 'Title not found in CrossRef database':
                        doi_link = f'<a href="https://www.google.com/search?q={title} {author}">Google Search</a>'
                    else:
                        doi_link = f'<a href="https://doi.org/{doi}">PDF</a>'

                    display(HTML(f"<b>Node ID:</b> {node_id}<br>"
                                 f"<b>Community ID:</b> {community_id}<br>"
                                 f"<b>Category:</b> {category}<br>"
                                 f"<b>Title:</b> {title}<br>"
                                 f"<b>Author:</b> {author}<br>"
                                 f"<b>Journal:</b> {journal}<br>"
                                 f"<b>Booktitle:</b> {booktitle}<br>"
                                 f'{doi_link}'
                                ))

                    community_nodes = get_community_info(node_id)
                    if community_nodes:
                        valid_nodes = [node for node in community_nodes if node in all_papers_df.index]
                        invalid_nodes = [node for node in community_nodes if node not in all_papers_df.index]

                        community_df = all_papers_df.loc[valid_nodes]
                        community_df = community_df[community_df.index < 1000]  # Filter node IDs < 1000

                        def doi_link2(row):
                          # Get the DOI for the title and authors
                          doi2 = find_doi_by_title_and_authors(row["Title"], row["Author"])

                          # Check if DOI is found
                          if doi2 == 'DOI not found':
                              return f'<a href="https://www.google.com/search?q={row["Title"]} {row["Author"]}">Google Search</a>'
                          else:
                              return f'<a href="https://doi.org/{doi2}">PDF</a>'

                        # Apply the doi_link2 function using a lambda function to create the 'Link' column
                        community_df['Link'] = community_df.apply(lambda row: doi_link2(row), axis=1)

                        with community_table_output:
                            display(HTML(community_df[['Category', 'Title', 'Author', 'Year', 'Link']].to_html(index=False, escape=False)))

                        with count_output:
                            print(f"Number of papers with node IDs not available in the dataframe: {len(invalid_nodes)}")
                            print(f"Node IDs not available in the dataframe: {invalid_nodes}")
                    else:
                        with community_table_output:
                            print("No papers found in the same community.")
        else:
            with details_output:
                print("No details available for the selected paper.")
    else:
        with details_output:
            print("Please select a paper from the dropdown.")

# Event handler for dropdown selection
def on_dropdown_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        selected_title = change['new']
        display_details(selected_title)

# Connect the dropdown to the event handler
dropdown_results.observe(on_dropdown_change)

# Initialize dropdown options
update_dropdown(None)
# Out:
# VBox(children=(Text(value='', description='Keyword:', placeholder='Enter keyword.'), Dropdown(description='Sea…

# %% [markdown]
# # Display Papers Based on Dropdown Category Selection

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display, HTML

# Assuming 'all_papers_df', 'titles_df', 'get_community_info', 'community_labels', and other necessary variables are defined

# Create a dropdown widget to select the category
category_dropdown = widgets.Dropdown(options=['Select'] + all_papers_df['Category'].unique().tolist(), description='Category')

# Create a dropdown widget to display paper titles within the selected category
title_dropdown = widgets.Dropdown(options=['Select'], description='Paper Title')

# Create output widgets for details, community table, and count
details_output = widgets.Output()
community_table_output = widgets.Output()
count_output = widgets.Output()

# Display the widgets
display(widgets.VBox([category_dropdown, title_dropdown, details_output, community_table_output, count_output]))

# Function to update the title dropdown based on the selected category
def update_title_dropdown(change):
    selected_category = change.new
    if selected_category != 'Select':
        titles = title_df[title_df['Category'] == selected_category]['Title'].tolist()
        title_dropdown.options = ['Select'] + titles
        title_dropdown.value = 'Select'  # Reset the selected paper title

# Connect the category dropdown to the update_title_dropdown function
category_dropdown.observe(update_title_dropdown, names='value')

# Function to display details and the table of papers in the same community
def display_details(selected_title):
    details_output.clear_output(wait=True)
    community_table_output.clear_output(wait=True)
    count_output.clear_output(wait=True)

    if selected_title != 'Select':
        selected_rows = all_papers_df[all_papers_df['Title'] == selected_title]
        if not selected_rows.empty:
            with details_output:
                for index, row in selected_rows.iterrows():
                    node_id = index
                    category = row['Category']
                    title = row['Title']
                    author = row['Author']
                    journal = row['Journal']
                    booktitle = row['Booktitle']

                    if node_id < len(community_labels):
                        community_id = community_labels[node_id]
                    else:
                        community_id = 'N/A'

                    doi = find_doi_by_title_and_authors(title,author)
                    if doi == 'Title not found in CrossRef database':
                        doi_link = f'<a href="https://www.google.com/search?q={title} {author}">Google Search</a>'
                    else:
                        doi_link = f'<a href="https://doi.org/{doi}">PDF</a>'

                    display(HTML(f"<b>Node ID:</b> {node_id}<br>"
                                 f"<b>Community ID:</b> {community_id}<br>"
                                 f"<b>Category:</b> {category}<br>"
                                 f"<b>Title:</b> {title}<br>"
                                 f"<b>Author:</b> {author}<br>"
                                 f"<b>Journal:</b> {journal}<br>"
                                 f"<b>Booktitle:</b> {booktitle}<br>"
                                 f'{doi_link}'
                                ))

                    community_nodes = get_community_info(node_id)
                    if community_nodes:
                        valid_nodes = [node for node in community_nodes if node in all_papers_df.index]
                        invalid_nodes = [node for node in community_nodes if node not in all_papers_df.index]

                        community_df = all_papers_df.loc[valid_nodes]
                        community_df = community_df[community_df.index < 1000]  # Filter node IDs < 1000

                        def doi_link2(row):
                          # Get the DOI for the title and authors
                          doi2 = find_doi_by_title_and_authors(row["Title"], row["Author"])

                          # Check if DOI is found
                          if doi2 == 'DOI not found':
                              return f'<a href="https://www.google.com/search?q={row["Title"]} {row["Author"]}">Google Search</a>'
                          else:
                              return f'<a href="https://doi.org/{doi2}">PDF</a>'

                        # Apply the doi_link2 function using a lambda function to create the 'Link' column
                        community_df['Link'] = community_df.apply(lambda row: doi_link2(row), axis=1)

                        with community_table_output:
                            display(HTML(community_df[['Category', 'Title', 'Author', 'Year', 'Link']].to_html(index=False, escape=False)))

                        with count_output:
                            print(f"Number of papers with node IDs not available in the dataframe: {len(invalid_nodes)}")
                            print(f"Node IDs not available in the dataframe: {invalid_nodes}")
                    else:
                        with community_table_output:
                            print("No papers found in the same community.")
        else:
            with details_output:
                print("No details available for the selected paper.")
    else:
        with details_output:
            print("Please select a paper from the dropdown.")

# Connect the title dropdown to the display_details function
title_dropdown.observe(lambda change: display_details(change.new), names='value')
# Out:
# VBox(children=(Dropdown(description='Category', options=('Select', 'Theory', 'Reinforcement_Learning', 'Geneti…
